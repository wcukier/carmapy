# %%
import carmapy

# %%
import carmapy.example


carma = carmapy.example.example_carma("test_coag")
carma.add_coag("Pure TiO2")
# Out:
# 7852726.9171485575 1916.7491879769314
# 5012476.900598573 1784.2764098003863

# %%
carma.run()
# Out:
#
#
#  Create CARMA Object ...
#
#
#
#    Add Group(s) ...
#
#
#
#  Add Pure TiO2...
#
#  Add Mg2SiO4 on TiO2...
#
#
#
#    Add Element(s) ...
#
#
#
#  Add Pure TiO2...
#
#  Add Mg2SiO4 Mantle...
#
#  Add TiO2 Core (Mg2SiO4)...
#
#
#
#    Add Solute(s) ...
#
#
#
#  Add H2SO4 Solute ...
#
#
#
#    Add Gas(es) ...
#
#
#
#  Add H2O Vapor ...
#
#            2
#
#  Add TiO2 Vapor ...
#
#           19
#
#  Add Mg2SiO4 Vapor ...
#
#           19
#
#    Add Nucleation ...
#
#    Add Growth ...
#
#    Add Coagulation ...
#
#
#
#  Initialize CARMA ...
#
#
#
# Particle grid structure (setupbins):
#
# NGROUP :       2
#
# NELEM  :       3
#
# NBIN   :      80
#
# Massmin:     1.780E-23   2.689E-23
#
# Mrat   :          2.00        2.00
#
# nelemg :       1     2
#
# itype  :       2     2     3
#
# ienconc:       1     2
#
# igelem :       1     2     2
#
# ncore  :       0     1
#
#
#
#  Coagulation group mapping:
#
#  ig jg icoag =            1           1           1
#
# ...

# %%
carma.coags[0].group
