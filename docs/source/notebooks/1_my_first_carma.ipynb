# %% [markdown]
# # My First Carma Object Model
#
# We are going to start by importing carmapy and creating a carma object.  Each carma object has a name that corresponds with a path to a directory that will be created upon running the model to house the model and its output—we will name this carma object "my_first_carma"

# %%
import carmapy

carma = carmapy.Carma("my_first_carma")

# %% [markdown]
# ## Setting Time Steps
#
# We will now tell carmapy its timestep, along with how often to output data, and how many timesteps to run

# %%
# carma.set_stepping(dt=100, output_gap=800, n_tstep=24000)
carma.set_stepping(dt=100, output_gap=100, n_tstep=3000)

# %% [markdown]
# The parameters tell carmapy the following
#  - `dt` is the time step, in seconds
#  - `output_gap` is the number of time steps between each time the CARMA simulation writes to file
#  - `n_tstep` is the total number of timesteps to run CARMA for

# %% [markdown]
# ## Setting Atmospheric Structure and Physical Parameters
#
# For this example we will use the example atmopsheric structure that is included in carmapy but you of course can provide your own.  This atmospheric structure comes from a sonora diamondback ([Morley et al. 2024](https://doi.org/10.48550/arXiv.2402.00758)) run of a 1000 K solar-metalicity brown dwarf with a surface gravity of 31,600 cm/s² ($f_\text{sed} = 4$)

# %%
P_levs, T_levs, kzz_levs, mu_levs = carmapy.example.example_levels()

carma.add_P(P_levs)
carma.add_T(T_levs)
carma.add_kzz(kzz_levs)

# %% [markdown]
# Note that all of the inputs to carmapy are in cgs units so the units of `P_levs` is baryes, `T_levs` is in K, and `kzz_levs` is in cm²/s.  Each of these arrays are "levels" arrays which mean they describe the atmosphere at the boundary between layers—carmapy will model the formation of clouds at the "centers" location, between each of the provided "levels" locations.  Thus, if you want $N$ locations vertically where clouds might form, your "levels" arrays must be $N+1$ elements long.
#
# Also note that the first element of each array corresponds to the bottom of the atmosphere and the last element in each array corresponds to the top of the atmosphere.
#
# We also need to specify the surface gravity and the mean molecular weight of the atmosphere.  While our mean molecular weight varies throughout the atmosphere, carmapy requires a single value of the mean molecular weight to represent the entire atmosphere—in this case we will use the mean molecular weight at the bottom of the atmosphere

# %%
carma.set_physical_params(surface_grav=31600,
                            wt_mol=mu_levs[0])

# %% [markdown]
# Here we set the surface gravity to 31,600 cm/s² using the `surface_grav` argument and the mean molecular weight to the mean molecular weight at the bottom of our atmosphere using the `wt_mol` argument.
#
# We also need to tell CARMApy that the atmosphere is dominated by hydrogen so it can set the viscosity, thermal conductivity, and specific heat of the atmosphere accordingly

# %%
carma.set_atmospheric_parameters_from_defaults("Pure H2")

# %% [markdown]
# Note that you could instead set the visocisty, thermal conductivity, and specific heat manually with `carma.set_atmospheric_parameters()`
#
# Since we do not have altitude levels, we can tell carmapy to calculate the altitudes for us.

# %%
carma.calculate_z()

# %% [markdown]
# Since we have them, we can instead optionally use the complete mean molecular weight profile of our atmosphere for added accuracy:

# %%
carma.calculate_z(mu_levs)

# %% [markdown]
# For more accurate cloud calculations, sometimes we need deeper atmospheres than those commonly provided by evolutionary codes.  In those cases, we can tell carmapy to extend the bottom of the atmosphere adiabatically to a deeper pressure.

# %%
carma.extend_atmosphere(1e10)

# %% [markdown]
# Above we extended the atmosphere to a pressure of $10^{10}$ baryes.

# %% [markdown]
# ## Setting Cloud Physics
#
# carmapy requires that we tell it which species we should let form.  We do so by adding groups—types of particles that can form.  There are two types of groups:
#
# 1. Homogeneous Groups: These groups are particles which form via homogeneous nucleation and thus do not need a seed particle to form
# 2. Heterogeneous Groups: These groups are particles which consist of one specie which heterogeneously nucleated onto another specie, the latter of which serves as a seed particle.
#
# We can add a homogeneous group and then a heterogeneous group that nucleates on the homogeneous group as follows:

# %%
carma.add_hom_group("TiO2", 1e-8)
carma.add_het_group("Mg2SiO4", "TiO2", 1e-8 * 2**(1/3))

# %% [markdown]
# `carma.add_hom_group("TiO2", 1e-8)` tells carmapy to allow TiO₂ to homogeneously condense with a minimum radius of $10^{-8}$ cm using the physical properties of TiO₂ preprogrammed into carmapy (some of these properties can be changed: see the documentation for Elements and Gasses once they are written).
#
# `carma.add_het_group("Mg2SiO4", "TiO2", 1e-8 * 2**(1/3))` similarly tells carmapy to allow Mg₂SiO₄ to heterogeneously condense upon the TiO₂ seed particles in the group above.  This group has a minimum particle radius of $1.41 \times 10^{-8}$ cm.  Note that a homogeneous group must be created before a heterogeneous group can be defined to condense upon it.
#
# Any number of homogeneous and heterogeneous groups can be created, we created only 2 here for simplicity's sake.
#
# Unfortunately due to how CARMA was programmed, we are only able to provide a limited selection of species at this time.  You can see the supported species as follows:

# %%
carmapy.available_species()
# Out:
# ['KCl', 'ZnS', 'Na2S', 'MnS', 'Cr', 'Mg2SiO4', 'Fe', 'TiO2', 'Al2O3']

# %% [markdown]
# Additionally, the interaction term, `mucos`, for heterogeneously nucleating particles is only preprogrammed for certain combinations of species.  To see which species a given specie is able to condense upon without manually specifying `mucos` you can run the following code:

# %%
carmapy.included_mucos("Mg2SiO4")
# Out:
# {'TiO2': 0.995}

# %% [markdown]
# This indicates that Mg₂SiO₄ has an included interaction term for when it heterogeneously nucleates onto TiO₂.  If this term was not included in carmapy or we wanted to explore how the model changes if this interaction term is weaker we could, instead of running the above code to add groups, uncomment and run the below code:

# %%
# carma.add_hom_group("TiO2", 1e-8)
# carma.add_het_group("Mg2SiO4", "TiO2", 1e-8 * 2**(1/3), mucos=0.9)

# %% [markdown]
# ## Atmospheric Composition

# %% [markdown]
# We finaly need to tell carma the gas abundances for each gas resevoir that is limiting for each species.  (The limiting gas for each specie has defaults hard-coded—see the defaults documentation page once it is written).  The most common way to do that is to calculate the gas abundance at the base of each clouds—the place where the saturation vapor pressure for the specie reaches the atmospheric pressure—and consider that the gas mixing ratio of the specie at the bottom of the atmopshere.  Included in carmapy is a helper function which uses [fastchem](https://github.com/newstrangeworlds/fastchem) to calculate these gas phase abundances.

# %%
carmapy.chemistry.populate_abundances_at_cloud_base(carma)

# %% [markdown]
# If instead you want to set the gas abundances manually, see [Carma.set_nmr()](https://carmapy.readthedocs.io/en/latest/_autosummary/carmapy.Carma.html#carmapy.Carma.set_nmr)

# %% [markdown]
# ## Running the Model

# %% [markdown]
# To run the model all you need to do now is call `carma.run()` by uncommenting the following cell and running it.  Note that the simulation should take 15-25 minutes to run, dependending on your computer, and will give you multiple warnings/errors about negative gas concentrations and conditions at the beginning of your timestep—this is normal and expected.

# %%
# carma.run()
# Out:
#
#
#  Create CARMA Object ...
#
#
#
#    Add Group(s) ...
#
#
#
#  Add Pure TiO2...
#
#  Add Mg2SiO4 on TiO2...
#
#
#
#    Add Element(s) ...
#
#
#
#  Add Pure TiO2...
#
#  Add Mg2SiO4 Mantle...
#
#  Add TiO2 Core (Mg2SiO4)...
#
#
#
#    Add Solute(s) ...
#
#
#
#  Add H2SO4 Solute ...
#
#
#
#    Add Gas(es) ...
#
#
#
#  Add H2O Vapor ...
#
#            2
#
#  Add TiO2 Vapor ...
#
#           19
#
#  Add Mg2SiO4 Vapor ...
#
#           19
#
#    Add Nucleation ...
#
#    Add Growth ...
#
#    Add Coagulation ...
#
#
#
#  Initialize CARMA ...
#
#
#
# Particle grid structure (setupbins):
#
# NGROUP :       2
#
# NELEM  :       3
#
# NBIN   :      80
#
# Massmin:     1.780E-23   2.689E-23
#
# Mrat   :          2.00        2.00
#
# nelemg :       1     2
#
# itype  :       2     2     3
#
# ienconc:       1     2
#
# igelem :       1     2     2
#
# ncore  :       0     1
#
#
#
#  Coagulation group mapping:
#
#  ig jg icoag =            1           1           0
#
#  ig jg icoag =            1           2           0
#
#  ig jg icoag =            2           1           0
#
#  ig jg icoag =            2           2           0
#
#
#
#  Coagulation element mapping:
#
#  ielem ig icoagelem icomp(ielem) =            1           1           0           2
#
#  ielem ig icoagelem icomp(ielem) =            1           2           0           2
#
#  ielem ig icoagelem icomp(ielem) =            2           1           0           3
#
#  ielem ig icoagelem icomp(ielem) =            2           2           0           3
#
#  ielem ig icoagelem icomp(ielem) =            3           1           0           2
#
#  ielem ig icoagelem icomp(ielem) =            3           2           0           2
#
#
#
#  Coagulation bin mapping arrays
#
#  igrp, ibin =            1           1
#
#  igrp, ibin =            1           2
#
#  igrp, ibin =            1           3
#
#  igrp, ibin =            2           1
#
#  igrp, ibin =            2           2
#
#  igrp, ibin =            2           3
#
#
#
#  Nucleation mapping arrays (setupnuc):
#
#
#
#  Elements mapping:
#
#  ielem,nnucelem=           1           1
#
#  jfrom,inucelem=             1           1
#
#  ielem,nnucelem=           2           1
#
#  jfrom,inucelem=             1           1
#
#  ielem,nnucelem=           3           1
#
#  jfrom,inucelem=             1           1
#
#
#
#  Bin mapping:
#
#
#
#  Groups (from, to) =            1           1
#
#    ibin,nnucbin=           1           1
#
#     inucbin=           1
#
#    ibin,nnucbin=           2           1
#
#     inucbin=           2
#
#    ibin,nnucbin=           3           1
#
#     inucbin=           3
#
#    ibin,nnucbin=           4           1
#
#     inucbin=           4
#
#    ibin,nnucbin=           5           1
#
#     inucbin=           5
#
#    ibin,nnucbin=           6           1
#
#     inucbin=           6
#
#    ibin,nnucbin=           7           1
#
#     inucbin=           7
#
#    ibin,nnucbin=           8           1
#
#     inucbin=           8
#
#    ibin,nnucbin=           9           1
#
#     inucbin=           9
#
#    ibin,nnucbin=          10           1
#
#     inucbin=          10
#
#    ibin,nnucbin=          11           1
#
#     inucbin=          11
#
#    ibin,nnucbin=          12           1
#
#     inucbin=          12
#
#    ibin,nnucbin=          13           1
#
#     inucbin=          13
#
#    ibin,nnucbin=          14           1
#
#     inucbin=          14
#
#    ibin,nnucbin=          15           1
#
#     inucbin=          15
#
#    ibin,nnucbin=          16           1
#
#     inucbin=          16
#
#    ibin,nnucbin=          17           1
#
#     inucbin=          17
#
#    ibin,nnucbin=          18           1
#
#     inucbin=          18
#
#    ibin,nnucbin=          19           1
#
#     inucbin=          19
#
#    ibin,nnucbin=          20           1
#
#     inucbin=          20
#
#    ibin,nnucbin=          21           1
#
#     inucbin=          21
#
#    ibin,nnucbin=          22           1
#
#     inucbin=          22
#
#    ibin,nnucbin=          23           1
#
#     inucbin=          23
#
#    ibin,nnucbin=          24           1
#
#     inucbin=          24
#
#    ibin,nnucbin=          25           1
#
#     inucbin=          25
#
#    ibin,nnucbin=          26           1
#
#     inucbin=          26
#
#    ibin,nnucbin=          27           1
#
#     inucbin=          27
#
#    ibin,nnucbin=          28           1
#
#     inucbin=          28
#
#    ibin,nnucbin=          29           1
#
#     inucbin=          29
#
#    ibin,nnucbin=          30           1
#
#     inucbin=          30
#
#    ibin,nnucbin=          31           1
#
#     inucbin=          31
#
#    ibin,nnucbin=          32           1
#
#     inucbin=          32
#
#    ibin,nnucbin=          33           1
#
#     inucbin=          33
#
#    ibin,nnucbin=          34           1
#
#     inucbin=          34
#
#    ibin,nnucbin=          35           1
#
#     inucbin=          35
#
#    ibin,nnucbin=          36           1
#
#     inucbin=          36
#
#    ibin,nnucbin=          37           1
#
#     inucbin=          37
#
#    ibin,nnucbin=          38           1
#
#     inucbin=          38
#
#    ibin,nnucbin=          39           1
#
#     inucbin=          39
#
#    ibin,nnucbin=          40           1
#
#     inucbin=          40
#
#    ibin,nnucbin=          41           1
#
#     inucbin=          41
#
#    ibin,nnucbin=          42           1
#
#     inucbin=          42
#
#    ibin,nnucbin=          43           1
#
#     inucbin=          43
#
#    ibin,nnucbin=          44           1
#
#     inucbin=          44
#
#    ibin,nnucbin=          45           1
#
#     inucbin=          45
#
#    ibin,nnucbin=          46           1
#
#     inucbin=          46
#
#    ibin,nnucbin=          47           1
#
#     inucbin=          47
#
#    ibin,nnucbin=          48           1
#
#     inucbin=          48
#
#    ibin,nnucbin=          49           1
#
#     inucbin=          49
#
#    ibin,nnucbin=          50           1
#
#     inucbin=          50
#
#    ibin,nnucbin=          51           1
#
#     inucbin=          51
#
#    ibin,nnucbin=          52           1
#
#     inucbin=          52
#
#    ibin,nnucbin=          53           1
#
#     inucbin=          53
#
#    ibin,nnucbin=          54           1
#
#     inucbin=          54
#
#    ibin,nnucbin=          55           1
#
#     inucbin=          55
#
#    ibin,nnucbin=          56           1
#
#     inucbin=          56
#
#    ibin,nnucbin=          57           1
#
#     inucbin=          57
#
#    ibin,nnucbin=          58           1
#
#     inucbin=          58
#
#    ibin,nnucbin=          59           1
#
#     inucbin=          59
#
#    ibin,nnucbin=          60           1
#
#     inucbin=          60
#
#    ibin,nnucbin=          61           1
#
#     inucbin=          61
#
#    ibin,nnucbin=          62           1
#
#     inucbin=          62
#
#    ibin,nnucbin=          63           1
#
#     inucbin=          63
#
#    ibin,nnucbin=          64           1
#
#     inucbin=          64
#
#    ibin,nnucbin=          65           1
#
#     inucbin=          65
#
#    ibin,nnucbin=          66           1
#
#     inucbin=          66
#
#    ibin,nnucbin=          67           1
#
#     inucbin=          67
#
#    ibin,nnucbin=          68           1
#
#     inucbin=          68
#
#    ibin,nnucbin=          69           1
#
#     inucbin=          69
#
#    ibin,nnucbin=          70           1
#
#     inucbin=          70
#
#    ibin,nnucbin=          71           1
#
#     inucbin=          71
#
#    ibin,nnucbin=          72           1
#
#     inucbin=          72
#
#    ibin,nnucbin=          73           1
#
#     inucbin=          73
#
#    ibin,nnucbin=          74           1
#
#     inucbin=          74
#
#    ibin,nnucbin=          75           1
#
#     inucbin=          75
#
#    ibin,nnucbin=          76           1
#
#     inucbin=          76
#
#    ibin,nnucbin=          77           1
#
#     inucbin=          77
#
#    ibin,nnucbin=          78           1
#
#     inucbin=          78
#
#    ibin,nnucbin=          79           1
#
#     inucbin=          79
#
#    ibin,nnucbin=          80           1
#
#     inucbin=          80
#
#
#
#  Groups (from, to) =            1           2
#
#    ibin,nnucbin=           1           1
#
#     inucbin=           1
#
#    ibin,nnucbin=           2           1
#
#     inucbin=           2
#
#    ibin,nnucbin=           3           1
#
#     inucbin=           3
#
#    ibin,nnucbin=           4           1
#
#     inucbin=           4
#
#    ibin,nnucbin=           5           1
#
#     inucbin=           5
#
#    ibin,nnucbin=           6           1
#
#     inucbin=           6
#
#    ibin,nnucbin=           7           1
#
#     inucbin=           7
#
#    ibin,nnucbin=           8           1
#
#     inucbin=           8
#
#    ibin,nnucbin=           9           1
#
#     inucbin=           9
#
#    ibin,nnucbin=          10           1
#
#     inucbin=          10
#
#    ibin,nnucbin=          11           1
#
#     inucbin=          11
#
#    ibin,nnucbin=          12           1
#
#     inucbin=          12
#
#    ibin,nnucbin=          13           1
#
#     inucbin=          13
#
#    ibin,nnucbin=          14           1
#
#     inucbin=          14
#
#    ibin,nnucbin=          15           1
#
#     inucbin=          15
#
#    ibin,nnucbin=          16           1
#
#     inucbin=          16
#
#    ibin,nnucbin=          17           1
#
#     inucbin=          17
#
#    ibin,nnucbin=          18           1
#
#     inucbin=          18
#
#    ibin,nnucbin=          19           1
#
#     inucbin=          19
#
#    ibin,nnucbin=          20           1
#
#     inucbin=          20
#
#    ibin,nnucbin=          21           1
#
#     inucbin=          21
#
#    ibin,nnucbin=          22           1
#
#     inucbin=          22
#
#    ibin,nnucbin=          23           1
#
#     inucbin=          23
#
#    ibin,nnucbin=          24           1
#
#     inucbin=          24
#
#    ibin,nnucbin=          25           1
#
#     inucbin=          25
#
#    ibin,nnucbin=          26           1
#
#     inucbin=          26
#
#    ibin,nnucbin=          27           1
#
#     inucbin=          27
#
#    ibin,nnucbin=          28           1
#
#     inucbin=          28
#
#    ibin,nnucbin=          29           1
#
#     inucbin=          29
#
#    ibin,nnucbin=          30           1
#
#     inucbin=          30
#
#    ibin,nnucbin=          31           1
#
#     inucbin=          31
#
#    ibin,nnucbin=          32           1
#
#     inucbin=          32
#
#    ibin,nnucbin=          33           1
#
#     inucbin=          33
#
#    ibin,nnucbin=          34           1
#
#     inucbin=          34
#
#    ibin,nnucbin=          35           1
#
#     inucbin=          35
#
#    ibin,nnucbin=          36           1
#
#     inucbin=          36
#
#    ibin,nnucbin=          37           1
#
#     inucbin=          37
#
#    ibin,nnucbin=          38           1
#
#     inucbin=          38
#
#    ibin,nnucbin=          39           1
#
#     inucbin=          39
#
#    ibin,nnucbin=          40           1
#
#     inucbin=          40
#
#    ibin,nnucbin=          41           1
#
#     inucbin=          41
#
#    ibin,nnucbin=          42           1
#
#     inucbin=          42
#
#    ibin,nnucbin=          43           1
#
#     inucbin=          43
#
#    ibin,nnucbin=          44           1
#
#     inucbin=          44
#
#    ibin,nnucbin=          45           1
#
#     inucbin=          45
#
#    ibin,nnucbin=          46           1
#
#     inucbin=          46
#
#    ibin,nnucbin=          47           1
#
#     inucbin=          47
#
#    ibin,nnucbin=          48           1
#
#     inucbin=          48
#
#    ibin,nnucbin=          49           1
#
#     inucbin=          49
#
#    ibin,nnucbin=          50           1
#
#     inucbin=          50
#
#    ibin,nnucbin=          51           1
#
#     inucbin=          51
#
#    ibin,nnucbin=          52           1
#
#     inucbin=          52
#
#    ibin,nnucbin=          53           1
#
#     inucbin=          53
#
#    ibin,nnucbin=          54           1
#
#     inucbin=          54
#
#    ibin,nnucbin=          55           1
#
#     inucbin=          55
#
#    ibin,nnucbin=          56           1
#
#     inucbin=          56
#
#    ibin,nnucbin=          57           1
#
#     inucbin=          57
#
#    ibin,nnucbin=          58           1
#
#     inucbin=          58
#
#    ibin,nnucbin=          59           1
#
#     inucbin=          59
#
#    ibin,nnucbin=          60           1
#
#     inucbin=          60
#
#    ibin,nnucbin=          61           1
#
#     inucbin=          61
#
#    ibin,nnucbin=          62           1
#
#     inucbin=          62
#
#    ibin,nnucbin=          63           1
#
#     inucbin=          63
#
#    ibin,nnucbin=          64           1
#
#     inucbin=          64
#
#    ibin,nnucbin=          65           1
#
#     inucbin=          65
#
#    ibin,nnucbin=          66           1
#
#     inucbin=          66
#
#    ibin,nnucbin=          67           1
#
#     inucbin=          67
#
#    ibin,nnucbin=          68           1
#
#     inucbin=          68
#
#    ibin,nnucbin=          69           1
#
#     inucbin=          69
#
#    ibin,nnucbin=          70           1
#
#     inucbin=          70
#
#    ibin,nnucbin=          71           1
#
#     inucbin=          71
#
#    ibin,nnucbin=          72           1
#
#     inucbin=          72
#
#    ibin,nnucbin=          73           1
#
#     inucbin=          73
#
#    ibin,nnucbin=          74           1
#
#     inucbin=          74
#
#    ibin,nnucbin=          75           1
#
#     inucbin=          75
#
#    ibin,nnucbin=          76           1
#
#     inucbin=          76
#
#    ibin,nnucbin=          77           1
#
#     inucbin=          77
#
#    ibin,nnucbin=          78           1
#
#     inucbin=          78
#
#    ibin,nnucbin=          79           1
#
#     inucbin=          79
#
#    ibin,nnucbin=          80           1
#
#     inucbin=          80
#
#
#
#  Groups (from, to) =            2           1
#
#    None for bin            1
#
#    ibin,nnucbin=           2           1
#
#     inucbin=           1
#
#    ibin,nnucbin=           3           1
#
#     inucbin=           2
#
#    ibin,nnucbin=           4           1
#
#     inucbin=           3
#
#    ibin,nnucbin=           5           1
#
#     inucbin=           4
#
#    ibin,nnucbin=           6           1
#
#     inucbin=           5
#
#    ibin,nnucbin=           7           1
#
#     inucbin=           6
#
#    ibin,nnucbin=           8           1
#
#     inucbin=           7
#
#    ibin,nnucbin=           9           1
#
#     inucbin=           8
#
#    ibin,nnucbin=          10           1
#
#     inucbin=           9
#
#    ibin,nnucbin=          11           1
#
#     inucbin=          10
#
#    ibin,nnucbin=          12           1
#
#     inucbin=          11
#
#    ibin,nnucbin=          13           1
#
#     inucbin=          12
#
#    ibin,nnucbin=          14           1
#
#     inucbin=          13
#
#    ibin,nnucbin=          15           1
#
#     inucbin=          14
#
#    ibin,nnucbin=          16           1
#
#     inucbin=          15
#
#    ibin,nnucbin=          17           1
#
#     inucbin=          16
#
#    ibin,nnucbin=          18           1
#
#     inucbin=          17
#
#    ibin,nnucbin=          19           1
#
#     inucbin=          18
#
#    ibin,nnucbin=          20           1
#
#     inucbin=          19
#
#    ibin,nnucbin=          21           1
#
#     inucbin=          20
#
#    ibin,nnucbin=          22           1
#
#     inucbin=          21
#
#    ibin,nnucbin=          23           1
#
#     inucbin=          22
#
#    ibin,nnucbin=          24           1
#
#     inucbin=          23
#
#    ibin,nnucbin=          25           1
#
#     inucbin=          24
#
#    ibin,nnucbin=          26           1
#
#     inucbin=          25
#
#    ibin,nnucbin=          27           1
#
#     inucbin=          26
#
#    ibin,nnucbin=          28           1
#
#     inucbin=          27
#
#    ibin,nnucbin=          29           1
#
#     inucbin=          28
#
#    ibin,nnucbin=          30           1
#
#     inucbin=          29
#
#    ibin,nnucbin=          31           1
#
#     inucbin=          30
#
#    ibin,nnucbin=          32           1
#
#     inucbin=          31
#
#    ibin,nnucbin=          33           1
#
#     inucbin=          32
#
#    ibin,nnucbin=          34           1
#
#     inucbin=          33
#
#    ibin,nnucbin=          35           1
#
#     inucbin=          34
#
#    ibin,nnucbin=          36           1
#
#     inucbin=          35
#
#    ibin,nnucbin=          37           1
#
#     inucbin=          36
#
#    ibin,nnucbin=          38           1
#
#     inucbin=          37
#
#    ibin,nnucbin=          39           1
#
#     inucbin=          38
#
#    ibin,nnucbin=          40           1
#
#     inucbin=          39
#
#    ibin,nnucbin=          41           1
#
#     inucbin=          40
#
#    ibin,nnucbin=          42           1
#
#     inucbin=          41
#
#    ibin,nnucbin=          43           1
#
#     inucbin=          42
#
#    ibin,nnucbin=          44           1
#
#     inucbin=          43
#
#    ibin,nnucbin=          45           1
#
#     inucbin=          44
#
#    ibin,nnucbin=          46           1
#
#     inucbin=          45
#
#    ibin,nnucbin=          47           1
#
#     inucbin=          46
#
#    ibin,nnucbin=          48           1
#
#     inucbin=          47
#
#    ibin,nnucbin=          49           1
#
#     inucbin=          48
#
#    ibin,nnucbin=          50           1
#
#     inucbin=          49
#
#    ibin,nnucbin=          51           1
#
#     inucbin=          50
#
#    ibin,nnucbin=          52           1
#
#     inucbin=          51
#
#    ibin,nnucbin=          53           1
#
#     inucbin=          52
#
#    ibin,nnucbin=          54           1
#
#     inucbin=          53
#
#    ibin,nnucbin=          55           1
#
#     inucbin=          54
#
#    ibin,nnucbin=          56           1
#
#     inucbin=          55
#
#    ibin,nnucbin=          57           1
#
#     inucbin=          56
#
#    ibin,nnucbin=          58           1
#
#     inucbin=          57
#
#    ibin,nnucbin=          59           1
#
#     inucbin=          58
#
#    ibin,nnucbin=          60           1
#
#     inucbin=          59
#
#    ibin,nnucbin=          61           1
#
#     inucbin=          60
#
#    ibin,nnucbin=          62           1
#
#     inucbin=          61
#
#    ibin,nnucbin=          63           1
#
#     inucbin=          62
#
#    ibin,nnucbin=          64           1
#
#     inucbin=          63
#
#    ibin,nnucbin=          65           1
#
#     inucbin=          64
#
#    ibin,nnucbin=          66           1
#
#     inucbin=          65
#
#    ibin,nnucbin=          67           1
#
#     inucbin=          66
#
#    ibin,nnucbin=          68           1
#
#     inucbin=          67
#
#    ibin,nnucbin=          69           1
#
#     inucbin=          68
#
#    ibin,nnucbin=          70           1
#
#     inucbin=          69
#
#    ibin,nnucbin=          71           1
#
#     inucbin=          70
#
#    ibin,nnucbin=          72           1
#
#     inucbin=          71
#
#    ibin,nnucbin=          73           1
#
#     inucbin=          72
#
#    ibin,nnucbin=          74           1
#
#     inucbin=          73
#
#    ibin,nnucbin=          75           1
#
#     inucbin=          74
#
#    ibin,nnucbin=          76           1
#
#     inucbin=          75
#
#    ibin,nnucbin=          77           1
#
#     inucbin=          76
#
#    ibin,nnucbin=          78           1
#
#     inucbin=          77
#
#    ibin,nnucbin=          79           1
#
#     inucbin=          78
#
#    ibin,nnucbin=          80           1
#
#     inucbin=          79
#
#
#
#  Groups (from, to) =            2           2
#
#    ibin,nnucbin=           1           1
#
#     inucbin=           1
#
#    ibin,nnucbin=           2           1
#
#     inucbin=           2
#
#    ibin,nnucbin=           3           1
#
#     inucbin=           3
#
#    ibin,nnucbin=           4           1
#
#     inucbin=           4
#
#    ibin,nnucbin=           5           1
#
#     inucbin=           5
#
#    ibin,nnucbin=           6           1
#
#     inucbin=           6
#
#    ibin,nnucbin=           7           1
#
#     inucbin=           7
#
#    ibin,nnucbin=           8           1
#
#     inucbin=           8
#
#    ibin,nnucbin=           9           1
#
#     inucbin=           9
#
#    ibin,nnucbin=          10           1
#
#     inucbin=          10
#
#    ibin,nnucbin=          11           1
#
#     inucbin=          11
#
#    ibin,nnucbin=          12           1
#
#     inucbin=          12
#
#    ibin,nnucbin=          13           1
#
#     inucbin=          13
#
#    ibin,nnucbin=          14           1
#
#     inucbin=          14
#
#    ibin,nnucbin=          15           1
#
#     inucbin=          15
#
#    ibin,nnucbin=          16           1
#
#     inucbin=          16
#
#    ibin,nnucbin=          17           1
#
#     inucbin=          17
#
#    ibin,nnucbin=          18           1
#
#     inucbin=          18
#
#    ibin,nnucbin=          19           1
#
#     inucbin=          19
#
#    ibin,nnucbin=          20           1
#
#     inucbin=          20
#
#    ibin,nnucbin=          21           1
#
#     inucbin=          21
#
#    ibin,nnucbin=          22           1
#
#     inucbin=          22
#
#    ibin,nnucbin=          23           1
#
#     inucbin=          23
#
#    ibin,nnucbin=          24           1
#
#     inucbin=          24
#
#    ibin,nnucbin=          25           1
#
#     inucbin=          25
#
#    ibin,nnucbin=          26           1
#
#     inucbin=          26
#
#    ibin,nnucbin=          27           1
#
#     inucbin=          27
#
#    ibin,nnucbin=          28           1
#
#     inucbin=          28
#
#    ibin,nnucbin=          29           1
#
#     inucbin=          29
#
#    ibin,nnucbin=          30           1
#
#     inucbin=          30
#
#    ibin,nnucbin=          31           1
#
#     inucbin=          31
#
#    ibin,nnucbin=          32           1
#
#     inucbin=          32
#
#    ibin,nnucbin=          33           1
#
#     inucbin=          33
#
#    ibin,nnucbin=          34           1
#
#     inucbin=          34
#
#    ibin,nnucbin=          35           1
#
#     inucbin=          35
#
#    ibin,nnucbin=          36           1
#
#     inucbin=          36
#
#    ibin,nnucbin=          37           1
#
#     inucbin=          37
#
#    ibin,nnucbin=          38           1
#
#     inucbin=          38
#
#    ibin,nnucbin=          39           1
#
#     inucbin=          39
#
#    ibin,nnucbin=          40           1
#
#     inucbin=          40
#
#    ibin,nnucbin=          41           1
#
#     inucbin=          41
#
#    ibin,nnucbin=          42           1
#
#     inucbin=          42
#
#    ibin,nnucbin=          43           1
#
#     inucbin=          43
#
#    ibin,nnucbin=          44           1
#
#     inucbin=          44
#
#    ibin,nnucbin=          45           1
#
#     inucbin=          45
#
#    ibin,nnucbin=          46           1
#
#     inucbin=          46
#
#    ibin,nnucbin=          47           1
#
#     inucbin=          47
#
#    ibin,nnucbin=          48           1
#
#     inucbin=          48
#
#    ibin,nnucbin=          49           1
#
#     inucbin=          49
#
#    ibin,nnucbin=          50           1
#
#     inucbin=          50
#
#    ibin,nnucbin=          51           1
#
#     inucbin=          51
#
#    ibin,nnucbin=          52           1
#
#     inucbin=          52
#
#    ibin,nnucbin=          53           1
#
#     inucbin=          53
#
#    ibin,nnucbin=          54           1
#
#     inucbin=          54
#
#    ibin,nnucbin=          55           1
#
#     inucbin=          55
#
#    ibin,nnucbin=          56           1
#
#     inucbin=          56
#
#    ibin,nnucbin=          57           1
#
#     inucbin=          57
#
#    ibin,nnucbin=          58           1
#
#     inucbin=          58
#
#    ibin,nnucbin=          59           1
#
#     inucbin=          59
#
#    ibin,nnucbin=          60           1
#
#     inucbin=          60
#
#    ibin,nnucbin=          61           1
#
#     inucbin=          61
#
#    ibin,nnucbin=          62           1
#
#     inucbin=          62
#
#    ibin,nnucbin=          63           1
#
#     inucbin=          63
#
#    ibin,nnucbin=          64           1
#
#     inucbin=          64
#
#    ibin,nnucbin=          65           1
#
#     inucbin=          65
#
#    ibin,nnucbin=          66           1
#
#     inucbin=          66
#
#    ibin,nnucbin=          67           1
#
#     inucbin=          67
#
#    ibin,nnucbin=          68           1
#
#     inucbin=          68
#
#    ibin,nnucbin=          69           1
#
#     inucbin=          69
#
#    ibin,nnucbin=          70           1
#
#     inucbin=          70
#
#    ibin,nnucbin=          71           1
#
#     inucbin=          71
#
#    ibin,nnucbin=          72           1
#
#     inucbin=          72
#
#    ibin,nnucbin=          73           1
#
#     inucbin=          73
#
#    ibin,nnucbin=          74           1
#
#     inucbin=          74
#
#    ibin,nnucbin=          75           1
#
#     inucbin=          75
#
#    ibin,nnucbin=          76           1
#
#     inucbin=          76
#
#    ibin,nnucbin=          77           1
#
#     inucbin=          77
#
#    ibin,nnucbin=          78           1
#
#     inucbin=          78
#
#    ibin,nnucbin=          79           1
#
#     inucbin=          79
#
#    ibin,nnucbin=          80           1
#
#     inucbin=          80
#
#
#
# Particle nucleation mapping arrays (setupnuc):
#
# inucgas  :       2     0     3
#
# inuc2elem:       1     3
#
# ievp2elem:       0     0     1
#
#
#
# Particle nucleation mapping arrays (setupnuc):
#
# inucgas  :       0     0     0
#
# inuc2elem:
#
# ievp2elem:       0     0     1
#
#
#
# Particle nucleation mapping arrays (setupnuc):
#
# inucgas  :       0     0     0
#
# inuc2elem:
#
# ievp2elem:       0     0     1
#
#
#
# solute number   :       1
#
# solute name:    Sulfuric Acid
#
# molecular weight:     9.808E+01
#
# mass density    :     1.840E+00
#
#
#
#  level          zc           p           t
#
#                (m)        (Pa)         (K)
#
#      1    5342.811************    6736.446
#
#      2   15954.163************    6644.265
#
#      3   26415.704************    6550.461
#
#      4   36724.930************    6455.089
#
#      5   46879.434************    6358.211
#
#      6   56876.917************    6259.893
#
#      7   66715.194************    6160.206
#
#      8   76392.200************    6059.227
#
#      9   85906.001************    5957.037
#
#     10   95254.800************    5853.721
#
#     11  104436.942************    5749.369
#
#     12  113450.923************    5644.075
#
#     13  122295.392************    5537.937
#
#     14  130969.161************    5431.054
#
#     15  139471.208************    5323.530
#
#     16  147800.679************    5215.472
#
#     17  155956.894************    5106.988
#
#     18  163939.34988416757.881    4998.189
#
#     19  171747.71776705818.649    4889.185
#
#     20  179381.85066546011.815    4780.089
#
#     21  186841.78357731887.443    4671.013
#
#     22  194127.72750085207.766    4562.071
#
#     23  201240.07543451342.890    4453.374
#
#     24  208179.39437696143.895    4345.033
#
#     25  214946.42932703230.096    4237.158
#
#     26  221542.09528371635.617    4129.856
#
#     27  227967.47724613767.667    4023.232
#
#     28  234223.82121353635.263    3917.390
#
#     29  240312.53518525312.545    3812.429
#
#     30  246235.18016071605.639    3708.445
#
#     31  251993.46113942896.088    3605.530
#
#     32  257589.22912096137.478    3503.772
#
#     33  263024.46510493984.964    3403.256
#
#     34  268301.278 9104040.081    3304.060
#
#     35  273421.896 7898195.593    3206.259
#
#     36  278388.660 6852067.111    3109.923
#
#     37  283214.197 5944500.000    3021.495
#
#     38  287910.351 5157100.000    2940.305
#
#     39  292476.941 4474000.000    2859.215
#
#     40  296914.281 3881400.000    2778.360
#
#     41  301223.479 3367250.000    2697.890
#
#     42  305404.618 2921200.000    2617.680
#
#     43  309457.800 2534250.000    2537.660
#
#     44  313383.501 2198600.000    2458.205
#
#     45  317183.820 1907400.000    2379.605
#
#     46  320859.995 1654750.000    2301.725
#
#     47  324413.614 1435550.000    2224.780
#
#     48  327846.072 1245400.000    2149.150
#
#     49  331159.755 1080450.000    2074.890
#
#     50  334357.676  937320.000    2002.040
#
#     51  337441.493  813165.000    1930.830
#
#     52  340438.471  705455.000    1876.455
#
#     53  343377.531  612010.000    1840.145
#
#     54  346256.691  530945.000    1802.705
#
#     55  349066.067  460620.000    1759.065
#
#     56  351790.027  399605.000    1705.440
#
#     57  354391.287  346670.000    1628.550
#
#     58  356853.575  300750.000    1541.650
#
#     59  359201.743  260915.000    1470.290
#
#     60  361456.636  226355.000    1411.830
#
#     61  363625.089  196370.000    1357.575
#
#     62  365708.981  170360.000    1304.810
#
#     63  367711.408  147795.000    1253.765
#
#     64  369643.108  128215.000    1209.245
#
#     65  371510.537  111235.000    1169.475
#
#     66  373312.959   96503.500    1128.700
#
#     67  375052.076   83719.000    1088.725
#
#     68  376731.116   72629.500    1051.245
#
#     69  378353.855   63009.000    1016.005
#
#     70  379922.497   54663.000     982.155
#
#     71  381439.597   47422.500     949.885
#
#     72  382907.934   41141.000     919.345
#
#     73  384330.387   35691.500     890.610
#
#     74  385709.845   30964.000     863.725
#
#     75  387049.313   26862.500     838.640
#
#     76  388351.327   23304.000     815.125
#
#     77  389618.036   20217.000     793.050
#
#     78  390851.771   17539.000     772.430
#
#     79  392054.750   15216.000     753.270
#
#     80  393229.363   13200.500     735.425
#
#     81  394377.321   11452.000     718.770
#
#     82  395500.470    9935.250     703.290
#
#     83  396600.657    8619.200     688.820
#
#     84  397678.944    7477.550     675.150
#
#     85  398736.533    6487.100     662.180
#
#     86  399774.552    5627.800     649.890
#
#     87  400794.179    4882.350     638.405
#
#     88  401796.868    4235.650     627.800
#
#     89  402783.966    3674.600     618.035
#
#     90  403756.729    3187.900     609.100
#
#     91  404716.429    2765.600     600.820
#
#     92  405663.173    2399.250     592.735
#
#     93  406596.853    2081.450     584.585
#
#     94  407517.744    1805.750     576.600
#
#     95  408427.058    1566.600     569.425
#
#     96  409326.611    1359.100     563.245
#
#     97  410217.650    1179.050     557.800
#
#     98  411100.861    1022.860     552.940
#
#     99  411976.505     887.385     548.300
#
#    100  412844.982     769.845     543.770
#
#    101  413706.623     667.870     539.470
#
#    102  414561.749     579.405     535.405
#
#    103  415410.708     502.660     531.560
#
#    104  416253.653     436.080     527.790
#
#    105  417090.262     378.315     523.785
#
#    106  417919.881     328.205     519.450
#
#    107  418742.062     284.735     514.820
#
#    108  419556.281     247.020     509.800
#
#    109  420362.019     214.300     504.480
#
#    110  421159.499     185.915     499.330
#
#    111  421949.470     161.290     494.630
#
#    112  422732.453     139.925     490.215
#
#    113  423508.657     121.390     485.970
#
#    114  424278.350     105.310     481.885
#
#    115  425041.749      91.360     477.945
#
#    116  425798.923      79.260     474.140
#
#    117  426550.441      68.760     470.455
#
#    118  427296.292      59.650     466.880
#
#    119  428036.341      51.750     463.425
#
#    120  428771.234      44.895     460.100
#
#    121  429500.736      38.950     456.910
#
#    122  430225.800      33.790     453.865
#
#    123  430945.885      29.315     450.990
#
#    124  431661.372      25.435     448.310
#
#    125  432373.668      22.065     445.855
#
#    126  433082.956      19.140     443.690
#
#
#
#  level          zl          pl
#
#                (m)        (Pa)
#
#      1       0.000************
#
#      2   10685.621************
#
#      3   21222.706************
#
#      4   31608.703************
#
#      5   41841.157************
#
#      6   51917.712************
#
#      7   61836.123************
#
#      8   71594.265************
#
#      9   81190.135************
#
#     10   90621.867************
#
#     11   99887.733************
#
#     12  108986.151************
#
#     13  117915.694************
#
#     14  126675.090************
#
#     15  135263.233************
#
#     16  143679.184************
#
#     17  151922.175************
#
#     18  159991.61494687513.222
#
#     19  167887.08482146002.540
#
#     20  175608.34971265634.758
#
#     21  183155.35261826388.873
#
#     22  190528.21453637386.014
#
#     23  197727.24046533029.519
#
#     24  204752.90940369656.262
#
#     25  211605.87935022631.528
#
#     26  218286.97930383828.665
#
#     27  224797.21126359442.568
#
#     28  231137.74222868092.766
#
#     29  237309.90019839177.760
#
#     30  243315.17117211447.331
#
#     31  249155.18914931763.947
#
#     32  254831.73412954028.228
#
#     33  260346.72411238246.729
#
#     34  265702.205 9749723.199
#
#     35  270900.350 8458356.962
#
#     36  275943.443 7338034.223
#
#     37  280833.877 6366100.000
#
#     38  285594.517 5522900.000
#
#     39  290226.185 4791300.000
#
#     40  294727.696 4156700.000
#
#     41  299100.865 3606100.000
#
#     42  303346.094 3128400.000
#
#     43  307463.143 2714000.000
#
#     44  311452.458 2354500.000
#
#     45  315314.544 2042700.000
#
#     46  319053.096 1772100.000
#
#     47  322666.895 1537400.000
#
#     48  326160.334 1333700.000
#
#     49  329531.810 1157100.000
#
#     50  332787.700 1003800.000
#
#     51  335927.652  870840.000
#
#     52  338955.334  755490.000
#
#     53  341921.608  655420.000
#
#     54  344833.454  568600.000
#
#     55  347679.927  493290.000
#
#     56  350452.207  427950.000
#
#     57  353127.847  371260.000
#
#     58  355654.727  322080.000
#
#     59  358052.423  279420.000
#
#     60  360351.063  242410.000
#
#     61  362562.208  210300.000
#
#     62  364687.970  182440.000
#
#     63  366729.992  158280.000
#
#     64  368692.823  137310.000
#
#     65  370593.393  119120.000
#
#     66  372427.680  103350.000
#
#     67  374198.238   89657.000
#
#     68  375905.914   77781.000
#
#     69  377556.317   67478.000
#
#     70  379151.393   58540.000
#
#     71  380693.600   50786.000
#
#     72  382185.593   44059.000
#
#     73  383630.274   38223.000
#
#     74  385030.499   33160.000
#
#     75  386389.191   28768.000
#
#     76  387709.436   24957.000
#
#     77  388993.218   21651.000
#
#     78  390242.854   18783.000
#
#     79  391460.688   16295.000
#
#     80  392648.811   14137.000
#
#     81  393809.916   12264.000
#
#     82  394944.727   10640.000
#
#     83  396056.214    9230.500
#
#     84  397145.101    8007.900
#
#     85  398212.786    6947.200
#
#     86  399260.280    6027.000
#
#     87  400288.823    5228.600
#
#     88  401299.535    4536.100
#
#     89  402294.200    3935.200
#
#     90  403273.731    3414.000
#
#     91  404239.726    2961.800
#
#     92  405193.131    2569.400
#
#     93  406133.216    2229.100
#
#     94  407060.490    1933.800
#
#     95  407974.998    1677.700
#
#     96  408879.118    1455.500
#
#     97  409774.103    1262.700
#
#     98  410661.196    1095.400
#
#     99  411540.526     950.320
#
#    100  412412.484     824.450
#
#    101  413277.480     715.240
#
#    102  414135.765     620.500
#
#    103  414987.732     538.310
#
#    104  415833.684     467.010
#
#    105  416673.622     405.150
#
#    106  417506.902     351.480
#
#    107  418332.860     304.930
#
#    108  419151.264     264.540
#
#    109  419961.297     229.500
#
#    110  420762.741     199.100
#
#    111  421556.257     172.730
#
#    112  422342.683     149.850
#
#    113  423122.223     130.000
#
#    114  423895.091     112.780
#
#    115  424661.609      97.840
#
#    116  425421.889      84.880
#
#    117  426175.958      73.640
#
#    118  426924.925      63.880
#
#    119  427667.659      55.420
#
#    120  428405.023      48.080
#
#    121  429137.445      41.710
#
#    122  429864.026      36.190
#
#    123  430587.574      31.390
#
#    124  431304.196      27.240
#
#    125  432018.547      23.630
#
#    126  432728.789      20.500
#
#    127  433437.123      17.780
#
#
#
#  istep, time           1   0.0000000000000000      my_first_carma
#
#  istep, time           2   100.00000000000000      my_first_carma
#
#
#
# gsolve::WARNING: negtive gas concentration reached for Mg2SiO4 Vapor : iz= 118,lat=  45.00,lon=-105.00,gc=-0.196E-60,gasprod= 0.000E+00,supsati=       NaN,supsatl=       NaN,t=466.88, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.241E-57,supsati=-0.1903435407E+00,supsatl=-0.1903435407E+00,t=466.88,d_gc=-0.357E-57,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for Mg2SiO4 Vapor : iz= 117,lat=  45.00,lon=-105.00,gc=-0.155E-60,gasprod= 0.000E+00,supsati=       NaN,supsatl=       NaN,t=470.45, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.331E-57,supsati=-0.5203264888E+00,supsatl=-0.5203264888E+00,t=470.45,d_gc=-0.409E-57,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for H2O Vapor : iz= 117,lat=  45.00,lon=-105.00,gc=-0.735E-71,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=470.45, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.409E-57,supsati=-0.1000000000E+01,supsatl=-0.1000000000E+01,t=470.45,d_gc=-0.409E-57,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for Mg2SiO4 Vapor : iz= 116,lat=  45.00,lon=-105.00,gc=-0.122E-60,gasprod= 0.000E+00,supsati=       NaN,supsatl=       NaN,t=474.14, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.416E-57,supsati=-0.7184054732E+00,supsatl=-0.7184054732E+00,t=474.14,d_gc=-0.467E-57,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for Mg2SiO4 Vapor : iz= 115,lat=  45.00,lon=-105.00,gc=-0.354E-60,gasprod= 0.000E+00,supsati=       NaN,supsatl=       NaN,t=477.94, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.501E-57,supsati=-0.8363572860E+00,supsatl=-0.8363572860E+00,t=477.94,d_gc=-0.534E-57,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for Mg2SiO4 Vapor : iz= 114,lat=  45.00,lon=-105.00,gc=-0.468E-60,gasprod= 0.000E+00,supsati=       NaN,supsatl=       NaN,t=481.88, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.590E-57,supsati=-0.9060193639E+00,supsatl=-0.9060193639E+00,t=481.88,d_gc=-0.611E-57,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for Mg2SiO4 Vapor : iz= 113,lat=  45.00,lon=-105.00,gc=-0.400E-60,gasprod= 0.000E+00,supsati=       NaN,supsatl=       NaN,t=485.97, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.685E-57,supsati=-0.9467019747E+00,supsatl=-0.9467019747E+00,t=485.97,d_gc=-0.698E-57,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for H2O Vapor : iz= 113,lat=  45.00,lon=-105.00,gc=-0.125E-70,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=485.97, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.698E-57,supsati=-0.1000000000E+01,supsatl=-0.1000000000E+01,t=485.97,d_gc=-0.698E-57,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for Mg2SiO4 Vapor : iz= 112,lat=  45.00,lon=-105.00,gc=-0.142E-60,gasprod= 0.000E+00,supsati=       NaN,supsatl=       NaN,t=490.22, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.790E-57,supsati=-0.9701950177E+00,supsatl=-0.9701950177E+00,t=490.22,d_gc=-0.798E-57,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for Mg2SiO4 Vapor : iz= 111,lat=  45.00,lon=-105.00,gc=-0.637E-60,gasprod= 0.000E+00,supsati=       NaN,supsatl=       NaN,t=494.63, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.907E-57,supsati=-0.9835734586E+00,supsatl=-0.9835734586E+00,t=494.63,d_gc=-0.911E-57,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for H2O Vapor : iz= 111,lat=  45.00,lon=-105.00,gc=-0.142E-70,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=494.63, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.911E-57,supsati=-0.1000000000E+01,supsatl=-0.1000000000E+01,t=494.63,d_gc=-0.911E-57,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for Mg2SiO4 Vapor : iz= 110,lat=  45.00,lon=-105.00,gc=-0.242E-60,gasprod= 0.000E+00,supsati=       NaN,supsatl=       NaN,t=499.33, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.104E-56,supsati=-0.9912207718E+00,supsatl=-0.9912207718E+00,t=499.33,d_gc=-0.104E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for TiO2 Vapor : iz= 108,lat=  45.00,lon=-105.00,gc=-0.100E-59,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=509.80, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.933E-57,supsati=-0.5900707742E-01,supsatl=-0.5900707742E-01,t=509.80,d_gc=-0.135E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for H2O Vapor : iz= 108,lat=  45.00,lon=-105.00,gc=-0.197E-70,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=509.80, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.135E-56,supsati=-0.1000000000E+01,supsatl=-0.1000000000E+01,t=509.80,d_gc=-0.135E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for TiO2 Vapor : iz= 107,lat=  45.00,lon=-105.00,gc=-0.139E-59,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=514.82, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.130E-56,supsati=-0.7402890391E+00,supsatl=-0.7402890391E+00,t=514.82,d_gc=-0.155E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for H2O Vapor : iz= 107,lat=  45.00,lon=-105.00,gc=-0.168E-70,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=514.82, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.155E-56,supsati=-0.1000000000E+01,supsatl=-0.1000000000E+01,t=514.82,d_gc=-0.155E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for TiO2 Vapor : iz= 106,lat=  45.00,lon=-105.00,gc=-0.168E-59,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=519.45, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.163E-56,supsati=-0.9179163638E+00,supsatl=-0.9179163638E+00,t=519.45,d_gc=-0.177E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for H2O Vapor : iz= 106,lat=  45.00,lon=-105.00,gc=-0.365E-70,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=519.45, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.177E-56,supsati=-0.1000000000E+01,supsatl=-0.1000000000E+01,t=519.45,d_gc=-0.177E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for TiO2 Vapor : iz= 105,lat=  45.00,lon=-105.00,gc=-0.242E-60,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=523.78, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.194E-56,supsati=-0.9712368813E+00,supsatl=-0.9712368813E+00,t=523.78,d_gc=-0.202E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for H2O Vapor : iz= 105,lat=  45.00,lon=-105.00,gc=-0.151E-70,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=523.78, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.202E-56,supsati=-0.1000000000E+01,supsatl=-0.1000000000E+01,t=523.78,d_gc=-0.202E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for TiO2 Vapor : iz= 104,lat=  45.00,lon=-105.00,gc=-0.187E-59,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=527.79, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.227E-56,supsati=-0.9887711488E+00,supsatl=-0.9887711488E+00,t=527.79,d_gc=-0.231E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for H2O Vapor : iz= 104,lat=  45.00,lon=-105.00,gc=-0.386E-70,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=527.79, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.231E-56,supsati=-0.1000000000E+01,supsatl=-0.1000000000E+01,t=527.79,d_gc=-0.231E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for TiO2 Vapor : iz= 103,lat=  45.00,lon=-105.00,gc=-0.233E-59,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=531.56, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.262E-56,supsati=-0.9952587270E+00,supsatl=-0.9952587270E+00,t=531.56,d_gc=-0.264E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for TiO2 Vapor : iz= 102,lat=  45.00,lon=-105.00,gc=-0.340E-60,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=535.40, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.301E-56,supsati=-0.9980088479E+00,supsatl=-0.9980088479E+00,t=535.40,d_gc=-0.302E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for TiO2 Vapor : iz= 101,lat=  45.00,lon=-105.00,gc=-0.275E-59,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=539.47, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.345E-56,supsati=-0.9991982783E+00,supsatl=-0.9991982783E+00,t=539.47,d_gc=-0.346E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for TiO2 Vapor : iz= 100,lat=  45.00,lon=-105.00,gc=-0.261E-59,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=543.77, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.395E-56,supsati=-0.9996909913E+00,supsatl=-0.9996909913E+00,t=543.77,d_gc=-0.396E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for H2O Vapor : iz=  99,lat=  45.00,lon=-105.00,gc=-0.126E-69,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=548.30, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.452E-56,supsati=-0.1000000000E+01,supsatl=-0.1000000000E+01,t=548.30,d_gc=-0.452E-56,d_t=  0.00
#
#
#
# gsolve::WARNING: negtive gas concentration reached for TiO2 Vapor : iz=  99,lat=  45.00,lon=-105.00,gc=-0.426E-61,gasprod= 0.000E+00,supsati=-0.100E+01,supsatl=-0.100E+01,t=548.30, setting gc to 1e-50*rhoa(iz)
#
# gsolve::ERROR - conditions at beginning of the step : gc= 0.452E-56,supsati=-0.9998855700E+00,supsatl=-0.9998855700E+00,t=548.30,d_gc=-0.452E-56,d_t=  0.00
#
#  istep, time           3   200.00000000000000      my_first_carma
#
#  istep, time           4   300.00000000000000      my_first_carma
#
#  istep, time           5   400.00000000000000      my_first_carma
#
#  istep, time           6   500.00000000000000      my_first_carma
#
#  istep, time           7   600.00000000000000      my_first_carma
#
#  istep, time           8   700.00000000000000      my_first_carma
#
#  istep, time           9   800.00000000000000      my_first_carma
#
#  istep, time          10   900.00000000000000      my_first_carma
#
#  istep, time          11   1000.0000000000000      my_first_carma
#
#  istep, time          12   1100.0000000000000      my_first_carma
#
#  istep, time          13   1200.0000000000000      my_first_carma
#
#  istep, time          14   1300.0000000000000      my_first_carma
#
#  istep, time          15   1400.0000000000000      my_first_carma
#
#  istep, time          16   1500.0000000000000      my_first_carma
#
#  istep, time          17   1600.0000000000000      my_first_carma
#
#  istep, time          18   1700.0000000000000      my_first_carma
#
#  istep, time          19   1800.0000000000000      my_first_carma
#
#  istep, time          20   1900.0000000000000      my_first_carma
#
#  istep, time          21   2000.0000000000000      my_first_carma
#
#  istep, time          22   2100.0000000000000      my_first_carma
#
#  istep, time          23   2200.0000000000000      my_first_carma
#
#  istep, time          24   2300.0000000000000      my_first_carma
#
#  istep, time          25   2400.0000000000000      my_first_carma
#
#  istep, time          26   2500.0000000000000      my_first_carma
#
#  istep, time          27   2600.0000000000000      my_first_carma
#
#  istep, time          28   2700.0000000000000      my_first_carma
#
#  istep, time          29   2800.0000000000000      my_first_carma
#
#  istep, time          30   2900.0000000000000      my_first_carma
#
#  istep, time          31   3000.0000000000000      my_first_carma
#
#  istep, time          32   3100.0000000000000      my_first_carma
#
#  istep, time          33   3200.0000000000000      my_first_carma
#
#  istep, time          34   3300.0000000000000      my_first_carma
#
#  istep, time          35   3400.0000000000000      my_first_carma
#
#  istep, time          36   3500.0000000000000      my_first_carma
#
#  istep, time          37   3600.0000000000000      my_first_carma
#
#  istep, time          38   3700.0000000000000      my_first_carma
#
#  istep, time          39   3800.0000000000000      my_first_carma
#
#  istep, time          40   3900.0000000000000      my_first_carma
#
#  istep, time          41   4000.0000000000000      my_first_carma
#
#  istep, time          42   4100.0000000000000      my_first_carma
#
#  istep, time          43   4200.0000000000000      my_first_carma
#
#  istep, time          44   4300.0000000000000      my_first_carma
#
# ...
#
#  istep, time        2765   276400.00000000000      my_first_carma
#
#  istep, time        2766   276500.00000000000      my_first_carma
#
#  istep, time        2767   276600.00000000000      my_first_carma
#
#  istep, time        2768   276700.00000000000      my_first_carma
#
#  istep, time        2769   276800.00000000000      my_first_carma
#
#  istep, time        2770   276900.00000000000      my_first_carma
#
#  istep, time        2771   277000.00000000000      my_first_carma
#
#  istep, time        2772   277100.00000000000      my_first_carma
#
#  istep, time        2773   277200.00000000000      my_first_carma
#
#  istep, time        2774   277300.00000000000      my_first_carma
#
#  istep, time        2775   277400.00000000000      my_first_carma
#
#  istep, time        2776   277500.00000000000      my_first_carma
#
#  istep, time        2777   277600.00000000000      my_first_carma
#
#  istep, time        2778   277700.00000000000      my_first_carma
#
#  istep, time        2779   277800.00000000000      my_first_carma
#
#  istep, time        2780   277900.00000000000      my_first_carma
#
#  istep, time        2781   278000.00000000000      my_first_carma
#
#  istep, time        2782   278100.00000000000      my_first_carma
#
#  istep, time        2783   278200.00000000000      my_first_carma
#
#  istep, time        2784   278300.00000000000      my_first_carma
#
#  istep, time        2785   278400.00000000000      my_first_carma
#
#  istep, time        2786   278500.00000000000      my_first_carma
#
#  istep, time        2787   278600.00000000000      my_first_carma
#
#  istep, time        2788   278700.00000000000      my_first_carma
#
#  istep, time        2789   278800.00000000000      my_first_carma
#
#  istep, time        2790   278900.00000000000      my_first_carma
#
#  istep, time        2791   279000.00000000000      my_first_carma
#
#  istep, time        2792   279100.00000000000      my_first_carma
#
#  istep, time        2793   279200.00000000000      my_first_carma
#
#  istep, time        2794   279300.00000000000      my_first_carma
#
#  istep, time        2795   279400.00000000000      my_first_carma
#
#  istep, time        2796   279500.00000000000      my_first_carma
#
#  istep, time        2797   279600.00000000000      my_first_carma
#
#  istep, time        2798   279700.00000000000      my_first_carma
#
#  istep, time        2799   279800.00000000000      my_first_carma
#
#  istep, time        2800   279900.00000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#  istep, time        2801   280000.00000000000      my_first_carma
#
#  istep, time        2802   280100.00000000000      my_first_carma
#
#  istep, time        2803   280200.00000000000      my_first_carma
#
#  istep, time        2804   280300.00000000000      my_first_carma
#
#  istep, time        2805   280400.00000000000      my_first_carma
#
#  istep, time        2806   280500.00000000000      my_first_carma
#
#  istep, time        2807   280600.00000000000      my_first_carma
#
#  istep, time        2808   280700.00000000000      my_first_carma
#
#  istep, time        2809   280800.00000000000      my_first_carma
#
#  istep, time        2810   280900.00000000000      my_first_carma
#
#  istep, time        2811   281000.00000000000      my_first_carma
#
#  istep, time        2812   281100.00000000000      my_first_carma
#
#  istep, time        2813   281200.00000000000      my_first_carma
#
#  istep, time        2814   281300.00000000000      my_first_carma
#
#  istep, time        2815   281400.00000000000      my_first_carma
#
#  istep, time        2816   281500.00000000000      my_first_carma
#
#  istep, time        2817   281600.00000000000      my_first_carma
#
#  istep, time        2818   281700.00000000000      my_first_carma
#
#  istep, time        2819   281800.00000000000      my_first_carma
#
#  istep, time        2820   281900.00000000000      my_first_carma
#
#  istep, time        2821   282000.00000000000      my_first_carma
#
#  istep, time        2822   282100.00000000000      my_first_carma
#
#  istep, time        2823   282200.00000000000      my_first_carma
#
#  istep, time        2824   282300.00000000000      my_first_carma
#
#  istep, time        2825   282400.00000000000      my_first_carma
#
#  istep, time        2826   282500.00000000000      my_first_carma
#
#  istep, time        2827   282600.00000000000      my_first_carma
#
#  istep, time        2828   282700.00000000000      my_first_carma
#
#  istep, time        2829   282800.00000000000      my_first_carma
#
#  istep, time        2830   282900.00000000000      my_first_carma
#
#  istep, time        2831   283000.00000000000      my_first_carma
#
#  istep, time        2832   283100.00000000000      my_first_carma
#
#  istep, time        2833   283200.00000000000      my_first_carma
#
#  istep, time        2834   283300.00000000000      my_first_carma
#
#  istep, time        2835   283400.00000000000      my_first_carma
#
#  istep, time        2836   283500.00000000000      my_first_carma
#
#  istep, time        2837   283600.00000000000      my_first_carma
#
#  istep, time        2838   283700.00000000000      my_first_carma
#
#  istep, time        2839   283800.00000000000      my_first_carma
#
#  istep, time        2840   283900.00000000000      my_first_carma
#
#  istep, time        2841   284000.00000000000      my_first_carma
#
#  istep, time        2842   284100.00000000000      my_first_carma
#
#  istep, time        2843   284200.00000000000      my_first_carma
#
#  istep, time        2844   284300.00000000000      my_first_carma
#
#  istep, time        2845   284400.00000000000      my_first_carma
#
#  istep, time        2846   284500.00000000000      my_first_carma
#
#  istep, time        2847   284600.00000000000      my_first_carma
#
#  istep, time        2848   284700.00000000000      my_first_carma
#
#  istep, time        2849   284800.00000000000      my_first_carma
#
#  istep, time        2850   284900.00000000000      my_first_carma
#
#  istep, time        2851   285000.00000000000      my_first_carma
#
#  istep, time        2852   285100.00000000000      my_first_carma
#
#  istep, time        2853   285200.00000000000      my_first_carma
#
#  istep, time        2854   285300.00000000000      my_first_carma
#
#  istep, time        2855   285400.00000000000      my_first_carma
#
#  istep, time        2856   285500.00000000000      my_first_carma
#
#  istep, time        2857   285600.00000000000      my_first_carma
#
#  istep, time        2858   285700.00000000000      my_first_carma
#
#  istep, time        2859   285800.00000000000      my_first_carma
#
#  istep, time        2860   285900.00000000000      my_first_carma
#
#  istep, time        2861   286000.00000000000      my_first_carma
#
#  istep, time        2862   286100.00000000000      my_first_carma
#
#  istep, time        2863   286200.00000000000      my_first_carma
#
#  istep, time        2864   286300.00000000000      my_first_carma
#
#  istep, time        2865   286400.00000000000      my_first_carma
#
#  istep, time        2866   286500.00000000000      my_first_carma
#
#  istep, time        2867   286600.00000000000      my_first_carma
#
#  istep, time        2868   286700.00000000000      my_first_carma
#
#  istep, time        2869   286800.00000000000      my_first_carma
#
#  istep, time        2870   286900.00000000000      my_first_carma
#
#  istep, time        2871   287000.00000000000      my_first_carma
#
#  istep, time        2872   287100.00000000000      my_first_carma
#
#  istep, time        2873   287200.00000000000      my_first_carma
#
#  istep, time        2874   287300.00000000000      my_first_carma
#
#  istep, time        2875   287400.00000000000      my_first_carma
#
#  istep, time        2876   287500.00000000000      my_first_carma
#
#  istep, time        2877   287600.00000000000      my_first_carma
#
#  istep, time        2878   287700.00000000000      my_first_carma
#
#  istep, time        2879   287800.00000000000      my_first_carma
#
#  istep, time        2880   287900.00000000000      my_first_carma
#
#  istep, time        2881   288000.00000000000      my_first_carma
#
#  istep, time        2882   288100.00000000000      my_first_carma
#
#  istep, time        2883   288200.00000000000      my_first_carma
#
#  istep, time        2884   288300.00000000000      my_first_carma
#
#  istep, time        2885   288400.00000000000      my_first_carma
#
#  istep, time        2886   288500.00000000000      my_first_carma
#
#  istep, time        2887   288600.00000000000      my_first_carma
#
#  istep, time        2888   288700.00000000000      my_first_carma
#
#  istep, time        2889   288800.00000000000      my_first_carma
#
#  istep, time        2890   288900.00000000000      my_first_carma
#
#  istep, time        2891   289000.00000000000      my_first_carma
#
#  istep, time        2892   289100.00000000000      my_first_carma
#
#  istep, time        2893   289200.00000000000      my_first_carma
#
#  istep, time        2894   289300.00000000000      my_first_carma
#
#  istep, time        2895   289400.00000000000      my_first_carma
#
#  istep, time        2896   289500.00000000000      my_first_carma
#
#  istep, time        2897   289600.00000000000      my_first_carma
#
#  istep, time        2898   289700.00000000000      my_first_carma
#
#  istep, time        2899   289800.00000000000      my_first_carma
#
#  istep, time        2900   289900.00000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#  istep, time        2901   290000.00000000000      my_first_carma
#
#  istep, time        2902   290100.00000000000      my_first_carma
#
#  istep, time        2903   290200.00000000000      my_first_carma
#
#  istep, time        2904   290300.00000000000      my_first_carma
#
#  istep, time        2905   290400.00000000000      my_first_carma
#
#  istep, time        2906   290500.00000000000      my_first_carma
#
#  istep, time        2907   290600.00000000000      my_first_carma
#
#  istep, time        2908   290700.00000000000      my_first_carma
#
#  istep, time        2909   290800.00000000000      my_first_carma
#
#  istep, time        2910   290900.00000000000      my_first_carma
#
#  istep, time        2911   291000.00000000000      my_first_carma
#
#  istep, time        2912   291100.00000000000      my_first_carma
#
#  istep, time        2913   291200.00000000000      my_first_carma
#
#  istep, time        2914   291300.00000000000      my_first_carma
#
#  istep, time        2915   291400.00000000000      my_first_carma
#
#  istep, time        2916   291500.00000000000      my_first_carma
#
#  istep, time        2917   291600.00000000000      my_first_carma
#
#  istep, time        2918   291700.00000000000      my_first_carma
#
#  istep, time        2919   291800.00000000000      my_first_carma
#
#  istep, time        2920   291900.00000000000      my_first_carma
#
#  istep, time        2921   292000.00000000000      my_first_carma
#
#  istep, time        2922   292100.00000000000      my_first_carma
#
#  istep, time        2923   292200.00000000000      my_first_carma
#
#  istep, time        2924   292300.00000000000      my_first_carma
#
#  istep, time        2925   292400.00000000000      my_first_carma
#
#  istep, time        2926   292500.00000000000      my_first_carma
#
#  istep, time        2927   292600.00000000000      my_first_carma
#
#  istep, time        2928   292700.00000000000      my_first_carma
#
#  istep, time        2929   292800.00000000000      my_first_carma
#
#  istep, time        2930   292900.00000000000      my_first_carma
#
#  istep, time        2931   293000.00000000000      my_first_carma
#
#  istep, time        2932   293100.00000000000      my_first_carma
#
#  istep, time        2933   293200.00000000000      my_first_carma
#
#  istep, time        2934   293300.00000000000      my_first_carma
#
#  istep, time        2935   293400.00000000000      my_first_carma
#
#  istep, time        2936   293500.00000000000      my_first_carma
#
#  istep, time        2937   293600.00000000000      my_first_carma
#
#  istep, time        2938   293700.00000000000      my_first_carma
#
#  istep, time        2939   293800.00000000000      my_first_carma
#
#  istep, time        2940   293900.00000000000      my_first_carma
#
#  istep, time        2941   294000.00000000000      my_first_carma
#
#  istep, time        2942   294100.00000000000      my_first_carma
#
#  istep, time        2943   294200.00000000000      my_first_carma
#
#  istep, time        2944   294300.00000000000      my_first_carma
#
#  istep, time        2945   294400.00000000000      my_first_carma
#
#  istep, time        2946   294500.00000000000      my_first_carma
#
#  istep, time        2947   294600.00000000000      my_first_carma
#
#  istep, time        2948   294700.00000000000      my_first_carma
#
#  istep, time        2949   294800.00000000000      my_first_carma
#
#  istep, time        2950   294900.00000000000      my_first_carma
#
#  istep, time        2951   295000.00000000000      my_first_carma
#
#  istep, time        2952   295100.00000000000      my_first_carma
#
#  istep, time        2953   295200.00000000000      my_first_carma
#
#  istep, time        2954   295300.00000000000      my_first_carma
#
#  istep, time        2955   295400.00000000000      my_first_carma
#
#  istep, time        2956   295500.00000000000      my_first_carma
#
#  istep, time        2957   295600.00000000000      my_first_carma
#
#  istep, time        2958   295700.00000000000      my_first_carma
#
#  istep, time        2959   295800.00000000000      my_first_carma
#
#  istep, time        2960   295900.00000000000      my_first_carma
#
#  istep, time        2961   296000.00000000000      my_first_carma
#
#  istep, time        2962   296100.00000000000      my_first_carma
#
#  istep, time        2963   296200.00000000000      my_first_carma
#
#  istep, time        2964   296300.00000000000      my_first_carma
#
#  istep, time        2965   296400.00000000000      my_first_carma
#
#  istep, time        2966   296500.00000000000      my_first_carma
#
#  istep, time        2967   296600.00000000000      my_first_carma
#
#  istep, time        2968   296700.00000000000      my_first_carma
#
#  istep, time        2969   296800.00000000000      my_first_carma
#
#  istep, time        2970   296900.00000000000      my_first_carma
#
#  istep, time        2971   297000.00000000000      my_first_carma
#
#  istep, time        2972   297100.00000000000      my_first_carma
#
#  istep, time        2973   297200.00000000000      my_first_carma
#
#  istep, time        2974   297300.00000000000      my_first_carma
#
#  istep, time        2975   297400.00000000000      my_first_carma
#
#  istep, time        2976   297500.00000000000      my_first_carma
#
#  istep, time        2977   297600.00000000000      my_first_carma
#
#  istep, time        2978   297700.00000000000      my_first_carma
#
#  istep, time        2979   297800.00000000000      my_first_carma
#
#  istep, time        2980   297900.00000000000      my_first_carma
#
#  istep, time        2981   298000.00000000000      my_first_carma
#
#  istep, time        2982   298100.00000000000      my_first_carma
#
#  istep, time        2983   298200.00000000000      my_first_carma
#
#  istep, time        2984   298300.00000000000      my_first_carma
#
#  istep, time        2985   298400.00000000000      my_first_carma
#
#  istep, time        2986   298500.00000000000      my_first_carma
#
#  istep, time        2987   298600.00000000000      my_first_carma
#
#  istep, time        2988   298700.00000000000      my_first_carma
#
#  istep, time        2989   298800.00000000000      my_first_carma
#
#  istep, time        2990   298900.00000000000      my_first_carma
#
#  istep, time        2991   299000.00000000000      my_first_carma
#
#  istep, time        2992   299100.00000000000      my_first_carma
#
#  istep, time        2993   299200.00000000000      my_first_carma
#
#  istep, time        2994   299300.00000000000      my_first_carma
#
#  istep, time        2995   299400.00000000000      my_first_carma
#
#  istep, time        2996   299500.00000000000      my_first_carma
#
#  istep, time        2997   299600.00000000000      my_first_carma
#
#  istep, time        2998   299700.00000000000      my_first_carma
#
#  istep, time        2999   299800.00000000000      my_first_carma
#
#  istep, time        3000   299900.00000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#
#
#  CARMA_Destroy() ...
#
#  Done

# %% [markdown]
# Note that when you call `carma.run()` a directory with the name `"my_first_carma"` (or whatever you set the name of your carma object as) should have been created.  The directory stores the state of the model along with the model output—do not move or delete it while the model is running.  The next tutorial will go over how to read the output from that directory.
