# %% [markdown]
# # My First Carma Object Model
#
# We are going to start by importing carmapy and creating a carma object.  Each carma object has a name that corresponds with a path to a directory that will be created upon running the model to house the model and its output—we will name this carma object "my_first_carma"

# %%
import carmapy

carma = carmapy.Carma("my_first_carma")

# %% [markdown]
# ## Setting Time Steps
#
# We will now tell carmapy its timestep, along with how often to output data, and how many timesteps to run

# %%
carma.set_stepping(dt=100, output_gap=400, n_tstep=24000)

# %% [markdown]
# The parameters tell carmapy the following
#  - `dt` is the time step, in seconds
#  - `output_gap` is the number of time steps between each time the CARMA simulation writes to file
#  - `n_tstep` is the total number of timesteps to run CARMA for

# %% [markdown]
# ## Setting Atmospheric Structure and Physical Parameters
#
# For this example we will use the example atmopsheric structure that is included in carmapy but you of course can provide your own.  This atmospheric structure comes from a sonora diamondback ([Morley et al. 2024](https://doi.org/10.48550/arXiv.2402.00758)) run of a 1000 K solar-metalicity brown dwarf with a surface gravity of 31,600 cm/s² ($f_\text{sed} = 4$)

# %%
P_levs, T_levs, kzz_levs, mu_levs = carmapy.example.example_levels()

carma.add_P(P_levs)
carma.add_T(T_levs)
carma.add_kzz(kzz_levs)

# %% [markdown]
# Note that all of the inputs to carmapy are in cgs units so the units of `P_levs` is baryes, `T_levs` is in K, and `kzz_levs` is in cm²/s.  Each of these arrays are "levels" arrays which mean they describe the atmosphere at the boundary between layers—carmapy will model the formation of clouds at the "centers" location, between each of the provided "levels" locations.  Thus, if you want $N$ locations vertically where clouds might form, your "levels" arrays must be $N+1$ elements long.
#
# Also note that the first element of each array corresponds to the bottom of the atmosphere and the last element in each array corresponds to the top of the atmosphere.
#
# We also need to specify the surface gravity, the mean molecular weight, and the metallicity of the atmosphere.  While our mean molecular weight varies throughout the atmosphere, carmapy requires a single value of the mean molecular weight to represent the entire atmosphere—in this case we will use the mean molecular weight at the bottom of the atmosphere.

# %%
carma.set_physical_params(surface_grav=31600,
                            wt_mol=mu_levs[0],
                            log_metallicity=1)

# %% [markdown]
# Here we set the surface gravity to 31,600 cm/s² using the `surface_grav` argument, the mean molecular weight to the mean molecular weight at the bottom of our atmosphere using the `wt_mol` argument, and the metallicity to be solar.
#
# Similarly, we need to tell CARMApy what the atmospheric viscosity and thermal conductivity is

# %%
carma.set_atmospheric_parameters_from_defaults("Pure H2")

# %% [markdown]
# Here we set the atmospheric parameters to be that of a pure hydrogen atmosphere.  To set this manually see `Carma.set_atmospheric_parameters()`.
#
# Since we do not have altitude levels, we can tell carmapy to calculate the altitudes for us.

# %%
carma.calculate_z()

# %% [markdown]
# Since we have them, we can instead optionally use the complete mean molecular weight profile of our atmosphere for added accuracy:

# %%
carma.calculate_z(mu_levs)

# %% [markdown]
# For more accurate cloud calculations, sometimes we need deeper atmospheres than those commonly provided by evolutionary codes.  In those cases, we can tell carmapy to extend the bottom of the atmosphere adiabatically to a deeper pressure.

# %%
carma.extend_atmosphere(1e10, wt_mol=mu_levs)

# %% [markdown]
# Above we extended the atmosphere to a pressure of $10^{10}$ baryes.

# %% [markdown]
# ## Setting Cloud Physics
#
# carmapy requires that we tell it which species we should let form.  We do so by adding groups—types of particles that can form.  There are two types of groups:
#
# 1. Homogeneous Groups: These groups are particles which form via homogeneous nucleation and thus do not need a seed particle to form
# 2. Heterogeneous Groups: These groups are particles which consist of one specie which heterogeneously nucleated onto another specie, the latter of which serves as a seed particle.
#
# We can add a homogeneous group and then a heterogeneous group that nucleates on the homogeneous group as follows:

# %%
carma.add_hom_group("TiO2", 1e-8)
carma.add_het_group("Mg2SiO4", "TiO2", 1e-8 * 2**(1/3))

# %% [markdown]
# `carma.add_hom_group("TiO2", 1e-8)` tells carmapy to allow TiO₂ to homogeneously condense with a minimum radius of $10^{-8}$ cm using the physical properties of TiO₂ preprogrammed into carmapy (some of these properties can be changed: see the documentation for Elements and Gasses once they are written).
#
# `carma.add_het_group("Mg2SiO4", "TiO2", 1e-8 * 2**(1/3))` similarly tells carmapy to allow Mg₂SiO₄ to heterogeneously condense upon the TiO₂ seed particles in the group above.  This group has a minimum particle radius of $1.41 \times 10^{-8}$ cm.  Note that a homogeneous group must be created before a heterogeneous group can be defined to condense upon it.
#
# Any number of homogeneous and heterogeneous groups can be created, we created only 2 here for simplicity's sake.
#
# CARMApy offers a number of default species; you can see the supported species as follows:

# %%
carmapy.available_species()
# Out:
# ['KCl', 'ZnS', 'Na2S', 'MnS', 'Cr', 'Mg2SiO4', 'Fe', 'TiO2', 'Al2O3']

# %% [markdown]
# If you wish to add your own species see [Custom Condensates](https://carmapy.readthedocs.io/en/latest/notebooks/4_custom_condensates.html)
#
# Additionally, the interaction term, `mucos`, for heterogeneously nucleating particles is only preprogrammed for certain combinations of species.  To see which species a given specie is able to condense upon without manually specifying `mucos` you can run the following code:

# %%
carmapy.included_mucos("Mg2SiO4")
# Out:
# {'TiO2': 0.995}

# %% [markdown]
# This indicates that Mg₂SiO₄ has an included interaction term for when it heterogeneously nucleates onto TiO₂.  If this term was not included in carmapy or we wanted to explore how the model changes if this interaction term is weaker we could, instead of running the above code to add groups, uncomment and run the below code:

# %%
# carma.add_hom_group("TiO2", 1e-8)
# carma.add_het_group("Mg2SiO4", "TiO2", 1e-8 * 2**(1/3), mucos=0.9)

# %% [markdown]
# ## Atmospheric Composition

# %% [markdown]
# We finaly need to tell carma the gas abundances for each gas resevoir that is limiting for each species.  (The limiting gas for each specie has defaults hard-coded—see the defaults documentation page once it is written).  The most common way to do that is to calculate the gas abundance at the base of each clouds—the place where the saturation vapor pressure for the specie reaches the atmospheric pressure—and consider that the gas mixing ratio of the specie at the bottom of the atmopshere.  Included in carmapy is a helper function which uses [fastchem](https://github.com/newstrangeworlds/fastchem) to calculate these gas phase abundances.

# %%
carmapy.chemistry.populate_abundances_at_cloud_base(carma)

# %% [markdown]
# If instead you want to set the gas abundances manually, see [Carma.set_nmr()](https://carmapy.readthedocs.io/en/latest/_autosummary/carmapy.Carma.html#carmapy.Carma.set_nmr)

# %% [markdown]
# ## Running the Model

# %% [markdown]
# To run the model all you need to do now is call `carma.run()` by uncommenting the following cell and running it.  Note that the simulation should take 15-25 minutes to run, dependending on your computer, and will give you multiple warnings/errors about negative gas concentrations and conditions at the beginning of your timestep—this is normal and expected.

# %%
carma.run()
# Out:
#
#
#  Create CARMA Object ...
#
#
#
#    Add Group(s) ...
#
#
#
#  Add Pure TiO2...
#
#  Add Mg2SiO4 on TiO2...
#
#
#
#    Add Element(s) ...
#
#
#
#  Add Pure TiO2...
#
#  Add Mg2SiO4 Mantle...
#
#  Add TiO2 Core (Mg2SiO4)...
#
#
#
#    Add Solute(s) ...
#
#
#
#  Add H2SO4 Solute ...
#
#
#
#    Add Gas(es) ...
#
#
#
#  Add H2O Vapor ...
#
#            2
#
#  Add TiO2 Vapor ...
#
#           19
#
#  Add Mg2SiO4 Vapor ...
#
#           19
#
#    Add Nucleation ...
#
#    Add Growth ...
#
#    Add Coagulation ...
#
#
#
#  Initialize CARMA ...
#
#
#
# Particle grid structure (setupbins):
#
# NGROUP :       2
#
# NELEM  :       3
#
# NBIN   :      80
#
# Massmin:     1.780E-23   2.689E-23
#
# Mrat   :          2.00        2.00
#
# nelemg :       1     2
#
# itype  :       2     2     3
#
# ienconc:       1     2
#
# igelem :       1     2     2
#
# ncore  :       0     1
#
#
#
#  Nucleation mapping arrays (setupnuc):
#
#
#
#  Elements mapping:
#
#  ielem,nnucelem=           1           1
#
#  jfrom,inucelem=             1           1
#
#  ielem,nnucelem=           2           1
#
#  jfrom,inucelem=             1           1
#
#  ielem,nnucelem=           3           1
#
#  jfrom,inucelem=             1           1
#
#
#
#  Bin mapping:
#
#
#
#  Groups (from, to) =            1           1
#
#    ibin,nnucbin=           1           1
#
#     inucbin=           1
#
#    ibin,nnucbin=           2           1
#
#     inucbin=           2
#
#    ibin,nnucbin=           3           1
#
#     inucbin=           3
#
#    ibin,nnucbin=           4           1
#
#     inucbin=           4
#
#    ibin,nnucbin=           5           1
#
#     inucbin=           5
#
#    ibin,nnucbin=           6           1
#
#     inucbin=           6
#
#    ibin,nnucbin=           7           1
#
#     inucbin=           7
#
#    ibin,nnucbin=           8           1
#
#     inucbin=           8
#
#    ibin,nnucbin=           9           1
#
#     inucbin=           9
#
#    ibin,nnucbin=          10           1
#
#     inucbin=          10
#
#    ibin,nnucbin=          11           1
#
#     inucbin=          11
#
#    ibin,nnucbin=          12           1
#
#     inucbin=          12
#
#    ibin,nnucbin=          13           1
#
#     inucbin=          13
#
#    ibin,nnucbin=          14           1
#
#     inucbin=          14
#
#    ibin,nnucbin=          15           1
#
#     inucbin=          15
#
#    ibin,nnucbin=          16           1
#
#     inucbin=          16
#
#    ibin,nnucbin=          17           1
#
#     inucbin=          17
#
#    ibin,nnucbin=          18           1
#
#     inucbin=          18
#
#    ibin,nnucbin=          19           1
#
#     inucbin=          19
#
#    ibin,nnucbin=          20           1
#
#     inucbin=          20
#
#    ibin,nnucbin=          21           1
#
#     inucbin=          21
#
#    ibin,nnucbin=          22           1
#
#     inucbin=          22
#
#    ibin,nnucbin=          23           1
#
#     inucbin=          23
#
#    ibin,nnucbin=          24           1
#
#     inucbin=          24
#
#    ibin,nnucbin=          25           1
#
#     inucbin=          25
#
#    ibin,nnucbin=          26           1
#
#     inucbin=          26
#
#    ibin,nnucbin=          27           1
#
#     inucbin=          27
#
#    ibin,nnucbin=          28           1
#
#     inucbin=          28
#
#    ibin,nnucbin=          29           1
#
#     inucbin=          29
#
#    ibin,nnucbin=          30           1
#
#     inucbin=          30
#
#    ibin,nnucbin=          31           1
#
#     inucbin=          31
#
#    ibin,nnucbin=          32           1
#
#     inucbin=          32
#
#    ibin,nnucbin=          33           1
#
#     inucbin=          33
#
#    ibin,nnucbin=          34           1
#
#     inucbin=          34
#
#    ibin,nnucbin=          35           1
#
#     inucbin=          35
#
#    ibin,nnucbin=          36           1
#
#     inucbin=          36
#
#    ibin,nnucbin=          37           1
#
#     inucbin=          37
#
#    ibin,nnucbin=          38           1
#
#     inucbin=          38
#
#    ibin,nnucbin=          39           1
#
#     inucbin=          39
#
#    ibin,nnucbin=          40           1
#
#     inucbin=          40
#
#    ibin,nnucbin=          41           1
#
#     inucbin=          41
#
#    ibin,nnucbin=          42           1
#
#     inucbin=          42
#
#    ibin,nnucbin=          43           1
#
#     inucbin=          43
#
#    ibin,nnucbin=          44           1
#
#     inucbin=          44
#
#    ibin,nnucbin=          45           1
#
#     inucbin=          45
#
#    ibin,nnucbin=          46           1
#
#     inucbin=          46
#
#    ibin,nnucbin=          47           1
#
#     inucbin=          47
#
#    ibin,nnucbin=          48           1
#
#     inucbin=          48
#
#    ibin,nnucbin=          49           1
#
#     inucbin=          49
#
#    ibin,nnucbin=          50           1
#
#     inucbin=          50
#
#    ibin,nnucbin=          51           1
#
#     inucbin=          51
#
#    ibin,nnucbin=          52           1
#
#     inucbin=          52
#
#    ibin,nnucbin=          53           1
#
#     inucbin=          53
#
#    ibin,nnucbin=          54           1
#
#     inucbin=          54
#
#    ibin,nnucbin=          55           1
#
#     inucbin=          55
#
#    ibin,nnucbin=          56           1
#
#     inucbin=          56
#
#    ibin,nnucbin=          57           1
#
#     inucbin=          57
#
#    ibin,nnucbin=          58           1
#
#     inucbin=          58
#
#    ibin,nnucbin=          59           1
#
#     inucbin=          59
#
#    ibin,nnucbin=          60           1
#
#     inucbin=          60
#
#    ibin,nnucbin=          61           1
#
#     inucbin=          61
#
#    ibin,nnucbin=          62           1
#
#     inucbin=          62
#
#    ibin,nnucbin=          63           1
#
#     inucbin=          63
#
#    ibin,nnucbin=          64           1
#
#     inucbin=          64
#
#    ibin,nnucbin=          65           1
#
#     inucbin=          65
#
#    ibin,nnucbin=          66           1
#
#     inucbin=          66
#
#    ibin,nnucbin=          67           1
#
#     inucbin=          67
#
#    ibin,nnucbin=          68           1
#
#     inucbin=          68
#
#    ibin,nnucbin=          69           1
#
#     inucbin=          69
#
#    ibin,nnucbin=          70           1
#
#     inucbin=          70
#
#    ibin,nnucbin=          71           1
#
#     inucbin=          71
#
#    ibin,nnucbin=          72           1
#
#     inucbin=          72
#
#    ibin,nnucbin=          73           1
#
#     inucbin=          73
#
#    ibin,nnucbin=          74           1
#
#     inucbin=          74
#
#    ibin,nnucbin=          75           1
#
#     inucbin=          75
#
#    ibin,nnucbin=          76           1
#
#     inucbin=          76
#
#    ibin,nnucbin=          77           1
#
#     inucbin=          77
#
#    ibin,nnucbin=          78           1
#
#     inucbin=          78
#
#    ibin,nnucbin=          79           1
#
#     inucbin=          79
#
#    ibin,nnucbin=          80           1
#
#     inucbin=          80
#
#
#
#  Groups (from, to) =            1           2
#
#    ibin,nnucbin=           1           1
#
#     inucbin=           1
#
#    ibin,nnucbin=           2           1
#
#     inucbin=           2
#
#    ibin,nnucbin=           3           1
#
#     inucbin=           3
#
#    ibin,nnucbin=           4           1
#
#     inucbin=           4
#
#    ibin,nnucbin=           5           1
#
#     inucbin=           5
#
#    ibin,nnucbin=           6           1
#
#     inucbin=           6
#
#    ibin,nnucbin=           7           1
#
#     inucbin=           7
#
#    ibin,nnucbin=           8           1
#
#     inucbin=           8
#
#    ibin,nnucbin=           9           1
#
#     inucbin=           9
#
#    ibin,nnucbin=          10           1
#
#     inucbin=          10
#
#    ibin,nnucbin=          11           1
#
#     inucbin=          11
#
#    ibin,nnucbin=          12           1
#
#     inucbin=          12
#
#    ibin,nnucbin=          13           1
#
#     inucbin=          13
#
#    ibin,nnucbin=          14           1
#
#     inucbin=          14
#
#    ibin,nnucbin=          15           1
#
#     inucbin=          15
#
#    ibin,nnucbin=          16           1
#
#     inucbin=          16
#
#    ibin,nnucbin=          17           1
#
#     inucbin=          17
#
#    ibin,nnucbin=          18           1
#
#     inucbin=          18
#
#    ibin,nnucbin=          19           1
#
#     inucbin=          19
#
#    ibin,nnucbin=          20           1
#
#     inucbin=          20
#
#    ibin,nnucbin=          21           1
#
#     inucbin=          21
#
#    ibin,nnucbin=          22           1
#
#     inucbin=          22
#
#    ibin,nnucbin=          23           1
#
#     inucbin=          23
#
#    ibin,nnucbin=          24           1
#
#     inucbin=          24
#
#    ibin,nnucbin=          25           1
#
#     inucbin=          25
#
#    ibin,nnucbin=          26           1
#
#     inucbin=          26
#
#    ibin,nnucbin=          27           1
#
#     inucbin=          27
#
#    ibin,nnucbin=          28           1
#
#     inucbin=          28
#
#    ibin,nnucbin=          29           1
#
#     inucbin=          29
#
#    ibin,nnucbin=          30           1
#
#     inucbin=          30
#
#    ibin,nnucbin=          31           1
#
#     inucbin=          31
#
#    ibin,nnucbin=          32           1
#
#     inucbin=          32
#
#    ibin,nnucbin=          33           1
#
#     inucbin=          33
#
#    ibin,nnucbin=          34           1
#
#     inucbin=          34
#
#    ibin,nnucbin=          35           1
#
#     inucbin=          35
#
#    ibin,nnucbin=          36           1
#
#     inucbin=          36
#
#    ibin,nnucbin=          37           1
#
#     inucbin=          37
#
#    ibin,nnucbin=          38           1
#
#     inucbin=          38
#
#    ibin,nnucbin=          39           1
#
#     inucbin=          39
#
#    ibin,nnucbin=          40           1
#
#     inucbin=          40
#
#    ibin,nnucbin=          41           1
#
#     inucbin=          41
#
#    ibin,nnucbin=          42           1
#
#     inucbin=          42
#
#    ibin,nnucbin=          43           1
#
#     inucbin=          43
#
#    ibin,nnucbin=          44           1
#
#     inucbin=          44
#
#    ibin,nnucbin=          45           1
#
#     inucbin=          45
#
#    ibin,nnucbin=          46           1
#
#     inucbin=          46
#
#    ibin,nnucbin=          47           1
#
#     inucbin=          47
#
#    ibin,nnucbin=          48           1
#
#     inucbin=          48
#
#    ibin,nnucbin=          49           1
#
#     inucbin=          49
#
#    ibin,nnucbin=          50           1
#
#     inucbin=          50
#
#    ibin,nnucbin=          51           1
#
#     inucbin=          51
#
#    ibin,nnucbin=          52           1
#
#     inucbin=          52
#
#    ibin,nnucbin=          53           1
#
#     inucbin=          53
#
#    ibin,nnucbin=          54           1
#
#     inucbin=          54
#
#    ibin,nnucbin=          55           1
#
#     inucbin=          55
#
#    ibin,nnucbin=          56           1
#
#     inucbin=          56
#
#    ibin,nnucbin=          57           1
#
#     inucbin=          57
#
#    ibin,nnucbin=          58           1
#
#     inucbin=          58
#
#    ibin,nnucbin=          59           1
#
#     inucbin=          59
#
#    ibin,nnucbin=          60           1
#
#     inucbin=          60
#
#    ibin,nnucbin=          61           1
#
#     inucbin=          61
#
#    ibin,nnucbin=          62           1
#
#     inucbin=          62
#
#    ibin,nnucbin=          63           1
#
#     inucbin=          63
#
#    ibin,nnucbin=          64           1
#
#     inucbin=          64
#
#    ibin,nnucbin=          65           1
#
#     inucbin=          65
#
#    ibin,nnucbin=          66           1
#
#     inucbin=          66
#
#    ibin,nnucbin=          67           1
#
#     inucbin=          67
#
#    ibin,nnucbin=          68           1
#
#     inucbin=          68
#
#    ibin,nnucbin=          69           1
#
#     inucbin=          69
#
#    ibin,nnucbin=          70           1
#
#     inucbin=          70
#
#    ibin,nnucbin=          71           1
#
#     inucbin=          71
#
#    ibin,nnucbin=          72           1
#
#     inucbin=          72
#
#    ibin,nnucbin=          73           1
#
#     inucbin=          73
#
#    ibin,nnucbin=          74           1
#
#     inucbin=          74
#
#    ibin,nnucbin=          75           1
#
#     inucbin=          75
#
#    ibin,nnucbin=          76           1
#
#     inucbin=          76
#
#    ibin,nnucbin=          77           1
#
#     inucbin=          77
#
#    ibin,nnucbin=          78           1
#
#     inucbin=          78
#
#    ibin,nnucbin=          79           1
#
#     inucbin=          79
#
#    ibin,nnucbin=          80           1
#
#     inucbin=          80
#
#
#
#  Groups (from, to) =            2           1
#
#    None for bin            1
#
#    ibin,nnucbin=           2           1
#
#     inucbin=           1
#
#    ibin,nnucbin=           3           1
#
#     inucbin=           2
#
#    ibin,nnucbin=           4           1
#
#     inucbin=           3
#
#    ibin,nnucbin=           5           1
#
#     inucbin=           4
#
#    ibin,nnucbin=           6           1
#
#     inucbin=           5
#
#    ibin,nnucbin=           7           1
#
#     inucbin=           6
#
#    ibin,nnucbin=           8           1
#
#     inucbin=           7
#
#    ibin,nnucbin=           9           1
#
#     inucbin=           8
#
#    ibin,nnucbin=          10           1
#
#     inucbin=           9
#
#    ibin,nnucbin=          11           1
#
#     inucbin=          10
#
#    ibin,nnucbin=          12           1
#
#     inucbin=          11
#
#    ibin,nnucbin=          13           1
#
#     inucbin=          12
#
#    ibin,nnucbin=          14           1
#
#     inucbin=          13
#
#    ibin,nnucbin=          15           1
#
#     inucbin=          14
#
#    ibin,nnucbin=          16           1
#
#     inucbin=          15
#
#    ibin,nnucbin=          17           1
#
#     inucbin=          16
#
#    ibin,nnucbin=          18           1
#
#     inucbin=          17
#
#    ibin,nnucbin=          19           1
#
#     inucbin=          18
#
#    ibin,nnucbin=          20           1
#
#     inucbin=          19
#
#    ibin,nnucbin=          21           1
#
#     inucbin=          20
#
#    ibin,nnucbin=          22           1
#
#     inucbin=          21
#
#    ibin,nnucbin=          23           1
#
#     inucbin=          22
#
#    ibin,nnucbin=          24           1
#
#     inucbin=          23
#
#    ibin,nnucbin=          25           1
#
#     inucbin=          24
#
#    ibin,nnucbin=          26           1
#
#     inucbin=          25
#
#    ibin,nnucbin=          27           1
#
#     inucbin=          26
#
#    ibin,nnucbin=          28           1
#
#     inucbin=          27
#
#    ibin,nnucbin=          29           1
#
#     inucbin=          28
#
#    ibin,nnucbin=          30           1
#
#     inucbin=          29
#
#    ibin,nnucbin=          31           1
#
#     inucbin=          30
#
#    ibin,nnucbin=          32           1
#
#     inucbin=          31
#
#    ibin,nnucbin=          33           1
#
#     inucbin=          32
#
#    ibin,nnucbin=          34           1
#
#     inucbin=          33
#
#    ibin,nnucbin=          35           1
#
#     inucbin=          34
#
#    ibin,nnucbin=          36           1
#
#     inucbin=          35
#
#    ibin,nnucbin=          37           1
#
#     inucbin=          36
#
#    ibin,nnucbin=          38           1
#
#     inucbin=          37
#
#    ibin,nnucbin=          39           1
#
#     inucbin=          38
#
#    ibin,nnucbin=          40           1
#
#     inucbin=          39
#
#    ibin,nnucbin=          41           1
#
#     inucbin=          40
#
#    ibin,nnucbin=          42           1
#
#     inucbin=          41
#
#    ibin,nnucbin=          43           1
#
#     inucbin=          42
#
#    ibin,nnucbin=          44           1
#
#     inucbin=          43
#
#    ibin,nnucbin=          45           1
#
#     inucbin=          44
#
#    ibin,nnucbin=          46           1
#
#     inucbin=          45
#
#    ibin,nnucbin=          47           1
#
#     inucbin=          46
#
#    ibin,nnucbin=          48           1
#
#     inucbin=          47
#
#    ibin,nnucbin=          49           1
#
#     inucbin=          48
#
#    ibin,nnucbin=          50           1
#
#     inucbin=          49
#
#    ibin,nnucbin=          51           1
#
#     inucbin=          50
#
#    ibin,nnucbin=          52           1
#
#     inucbin=          51
#
#    ibin,nnucbin=          53           1
#
#     inucbin=          52
#
#    ibin,nnucbin=          54           1
#
#     inucbin=          53
#
#    ibin,nnucbin=          55           1
#
#     inucbin=          54
#
#    ibin,nnucbin=          56           1
#
#     inucbin=          55
#
#    ibin,nnucbin=          57           1
#
#     inucbin=          56
#
#    ibin,nnucbin=          58           1
#
#     inucbin=          57
#
#    ibin,nnucbin=          59           1
#
#     inucbin=          58
#
#    ibin,nnucbin=          60           1
#
#     inucbin=          59
#
#    ibin,nnucbin=          61           1
#
#     inucbin=          60
#
#    ibin,nnucbin=          62           1
#
#     inucbin=          61
#
#    ibin,nnucbin=          63           1
#
#     inucbin=          62
#
#    ibin,nnucbin=          64           1
#
#     inucbin=          63
#
#    ibin,nnucbin=          65           1
#
#     inucbin=          64
#
#    ibin,nnucbin=          66           1
#
#     inucbin=          65
#
#    ibin,nnucbin=          67           1
#
#     inucbin=          66
#
#    ibin,nnucbin=          68           1
#
#     inucbin=          67
#
#    ibin,nnucbin=          69           1
#
#     inucbin=          68
#
#    ibin,nnucbin=          70           1
#
#     inucbin=          69
#
#    ibin,nnucbin=          71           1
#
#     inucbin=          70
#
#    ibin,nnucbin=          72           1
#
#     inucbin=          71
#
#    ibin,nnucbin=          73           1
#
#     inucbin=          72
#
#    ibin,nnucbin=          74           1
#
#     inucbin=          73
#
#    ibin,nnucbin=          75           1
#
#     inucbin=          74
#
#    ibin,nnucbin=          76           1
#
#     inucbin=          75
#
#    ibin,nnucbin=          77           1
#
#     inucbin=          76
#
#    ibin,nnucbin=          78           1
#
#     inucbin=          77
#
#    ibin,nnucbin=          79           1
#
#     inucbin=          78
#
#    ibin,nnucbin=          80           1
#
#     inucbin=          79
#
#
#
#  Groups (from, to) =            2           2
#
#    ibin,nnucbin=           1           1
#
#     inucbin=           1
#
#    ibin,nnucbin=           2           1
#
#     inucbin=           2
#
#    ibin,nnucbin=           3           1
#
#     inucbin=           3
#
#    ibin,nnucbin=           4           1
#
#     inucbin=           4
#
#    ibin,nnucbin=           5           1
#
#     inucbin=           5
#
#    ibin,nnucbin=           6           1
#
#     inucbin=           6
#
#    ibin,nnucbin=           7           1
#
#     inucbin=           7
#
#    ibin,nnucbin=           8           1
#
#     inucbin=           8
#
#    ibin,nnucbin=           9           1
#
#     inucbin=           9
#
#    ibin,nnucbin=          10           1
#
#     inucbin=          10
#
#    ibin,nnucbin=          11           1
#
#     inucbin=          11
#
#    ibin,nnucbin=          12           1
#
#     inucbin=          12
#
#    ibin,nnucbin=          13           1
#
#     inucbin=          13
#
#    ibin,nnucbin=          14           1
#
#     inucbin=          14
#
#    ibin,nnucbin=          15           1
#
#     inucbin=          15
#
#    ibin,nnucbin=          16           1
#
#     inucbin=          16
#
#    ibin,nnucbin=          17           1
#
#     inucbin=          17
#
#    ibin,nnucbin=          18           1
#
#     inucbin=          18
#
#    ibin,nnucbin=          19           1
#
#     inucbin=          19
#
#    ibin,nnucbin=          20           1
#
#     inucbin=          20
#
#    ibin,nnucbin=          21           1
#
#     inucbin=          21
#
#    ibin,nnucbin=          22           1
#
#     inucbin=          22
#
#    ibin,nnucbin=          23           1
#
#     inucbin=          23
#
#    ibin,nnucbin=          24           1
#
#     inucbin=          24
#
#    ibin,nnucbin=          25           1
#
#     inucbin=          25
#
#    ibin,nnucbin=          26           1
#
#     inucbin=          26
#
#    ibin,nnucbin=          27           1
#
#     inucbin=          27
#
#    ibin,nnucbin=          28           1
#
#     inucbin=          28
#
#    ibin,nnucbin=          29           1
#
#     inucbin=          29
#
#    ibin,nnucbin=          30           1
#
#     inucbin=          30
#
#    ibin,nnucbin=          31           1
#
#     inucbin=          31
#
#    ibin,nnucbin=          32           1
#
#     inucbin=          32
#
#    ibin,nnucbin=          33           1
#
#     inucbin=          33
#
#    ibin,nnucbin=          34           1
#
#     inucbin=          34
#
#    ibin,nnucbin=          35           1
#
#     inucbin=          35
#
#    ibin,nnucbin=          36           1
#
#     inucbin=          36
#
#    ibin,nnucbin=          37           1
#
#     inucbin=          37
#
#    ibin,nnucbin=          38           1
#
#     inucbin=          38
#
#    ibin,nnucbin=          39           1
#
#     inucbin=          39
#
#    ibin,nnucbin=          40           1
#
#     inucbin=          40
#
#    ibin,nnucbin=          41           1
#
#     inucbin=          41
#
#    ibin,nnucbin=          42           1
#
#     inucbin=          42
#
#    ibin,nnucbin=          43           1
#
#     inucbin=          43
#
#    ibin,nnucbin=          44           1
#
#     inucbin=          44
#
#    ibin,nnucbin=          45           1
#
#     inucbin=          45
#
#    ibin,nnucbin=          46           1
#
#     inucbin=          46
#
#    ibin,nnucbin=          47           1
#
#     inucbin=          47
#
#    ibin,nnucbin=          48           1
#
#     inucbin=          48
#
#    ibin,nnucbin=          49           1
#
#     inucbin=          49
#
#    ibin,nnucbin=          50           1
#
#     inucbin=          50
#
#    ibin,nnucbin=          51           1
#
#     inucbin=          51
#
#    ibin,nnucbin=          52           1
#
#     inucbin=          52
#
#    ibin,nnucbin=          53           1
#
#     inucbin=          53
#
#    ibin,nnucbin=          54           1
#
#     inucbin=          54
#
#    ibin,nnucbin=          55           1
#
#     inucbin=          55
#
#    ibin,nnucbin=          56           1
#
#     inucbin=          56
#
#    ibin,nnucbin=          57           1
#
#     inucbin=          57
#
#    ibin,nnucbin=          58           1
#
#     inucbin=          58
#
#    ibin,nnucbin=          59           1
#
#     inucbin=          59
#
#    ibin,nnucbin=          60           1
#
#     inucbin=          60
#
#    ibin,nnucbin=          61           1
#
#     inucbin=          61
#
#    ibin,nnucbin=          62           1
#
#     inucbin=          62
#
#    ibin,nnucbin=          63           1
#
#     inucbin=          63
#
#    ibin,nnucbin=          64           1
#
#     inucbin=          64
#
#    ibin,nnucbin=          65           1
#
#     inucbin=          65
#
#    ibin,nnucbin=          66           1
#
#     inucbin=          66
#
#    ibin,nnucbin=          67           1
#
#     inucbin=          67
#
#    ibin,nnucbin=          68           1
#
#     inucbin=          68
#
#    ibin,nnucbin=          69           1
#
#     inucbin=          69
#
#    ibin,nnucbin=          70           1
#
#     inucbin=          70
#
#    ibin,nnucbin=          71           1
#
#     inucbin=          71
#
#    ibin,nnucbin=          72           1
#
#     inucbin=          72
#
#    ibin,nnucbin=          73           1
#
#     inucbin=          73
#
#    ibin,nnucbin=          74           1
#
#     inucbin=          74
#
#    ibin,nnucbin=          75           1
#
#     inucbin=          75
#
#    ibin,nnucbin=          76           1
#
#     inucbin=          76
#
#    ibin,nnucbin=          77           1
#
#     inucbin=          77
#
#    ibin,nnucbin=          78           1
#
#     inucbin=          78
#
#    ibin,nnucbin=          79           1
#
#     inucbin=          79
#
#    ibin,nnucbin=          80           1
#
#     inucbin=          80
#
#
#
# Particle nucleation mapping arrays (setupnuc):
#
# inucgas  :       2     0     3
#
# inuc2elem:       1     3
#
# ievp2elem:       0     0     1
#
#
#
# Particle nucleation mapping arrays (setupnuc):
#
# inucgas  :       0     0     0
#
# inuc2elem:
#
# ievp2elem:       0     0     1
#
#
#
# Particle nucleation mapping arrays (setupnuc):
#
# inucgas  :       0     0     0
#
# inuc2elem:
#
# ievp2elem:       0     0     1
#
#
#
# solute number   :       1
#
# solute name:    Sulfuric Acid
#
# molecular weight:     9.808E+01
#
# mass density    :     1.840E+00
#
#
#
#  level          zc           p           t
#
#                (m)        (Pa)         (K)
#
#      1    5342.811************    6736.446
#
#      2   15954.163************    6644.265
#
#      3   26415.704************    6550.461
#
#      4   36724.930************    6455.089
#
#      5   46879.434************    6358.211
#
#      6   56876.917************    6259.893
#
#      7   66715.194************    6160.206
#
#      8   76392.200************    6059.227
#
#      9   85906.001************    5957.037
#
#     10   95254.800************    5853.721
#
#     11  104436.942************    5749.369
#
#     12  113450.923************    5644.075
#
#     13  122295.392************    5537.937
#
#     14  130969.161************    5431.054
#
#     15  139471.208************    5323.530
#
#     16  147800.679************    5215.472
#
#     17  155956.894************    5106.988
#
#     18  163939.34988416757.881    4998.189
#
#     19  171747.71776705818.649    4889.185
#
#     20  179381.85066546011.815    4780.089
#
#     21  186841.78357731887.443    4671.013
#
#     22  194127.72750085207.766    4562.071
#
#     23  201240.07543451342.890    4453.374
#
#     24  208179.39437696143.895    4345.033
#
#     25  214946.42932703230.096    4237.158
#
#     26  221542.09528371635.617    4129.856
#
#     27  227967.47724613767.667    4023.232
#
#     28  234223.82121353635.263    3917.390
#
#     29  240312.53518525312.545    3812.429
#
#     30  246235.18016071605.639    3708.445
#
#     31  251993.46113942896.088    3605.530
#
#     32  257589.22912096137.478    3503.772
#
#     33  263024.46510493984.964    3403.256
#
#     34  268301.278 9104040.081    3304.060
#
#     35  273421.896 7898195.593    3206.259
#
#     36  278388.660 6852067.111    3109.923
#
#     37  283208.789 5944500.000    3021.495
#
#     38  287891.086 5157100.000    2940.305
#
#     39  292438.324 4474000.000    2859.215
#
#     40  296851.790 3881400.000    2778.360
#
#     41  301131.995 3367250.000    2697.890
#
#     42  305280.103 2921200.000    2617.680
#
#     43  309298.397 2534250.000    2537.660
#
#     44  313187.871 2198600.000    2458.205
#
#     45  316951.336 1907400.000    2379.605
#
#     46  320590.623 1654750.000    2301.725
#
#     47  324107.562 1435550.000    2224.780
#
#     48  327503.977 1245400.000    2149.150
#
#     49  330782.819 1080450.000    2074.890
#
#     50  333947.533  937320.000    2002.040
#
#     51  337000.020  813165.000    1930.830
#
#     52  339967.045  705455.000    1876.455
#
#     53  342877.021  612010.000    1840.145
#
#     54  345728.171  530945.000    1802.705
#
#     55  348510.894  460620.000    1759.065
#
#     56  351209.620  399605.000    1705.440
#
#     57  353787.338  346670.000    1628.550
#
#     58  356227.614  300750.000    1541.650
#
#     59  358554.861  260915.000    1470.290
#
#     60  360789.774  226355.000    1411.830
#
#     61  362939.147  196370.000    1357.575
#
#     62  365004.865  170360.000    1304.810
#
#     63  366989.906  147795.000    1253.765
#
#     64  368904.690  128215.000    1209.245
#
#     65  370755.468  111235.000    1169.475
#
#     66  372541.451   96503.500    1128.700
#
#     67  374264.742   83719.000    1088.725
#
#     68  375928.746   72629.500    1051.245
#
#     69  377536.597   63009.000    1016.005
#
#     70  379090.446   54663.000     982.155
#
#     71  380593.089   47422.500     949.885
#
#     72  382047.279   41141.000     919.345
#
#     73  383455.954   35691.500     890.610
#
#     74  384822.021   30964.000     863.725
#
#     75  386148.481   26862.500     838.640
#
#     76  387437.853   23304.000     815.125
#
#     77  388692.259   20217.000     793.050
#
#     78  389914.007   17539.000     772.430
#
#     79  391105.294   15216.000     753.270
#
#     80  392268.493   13200.500     735.425
#
#     81  393405.293   11452.000     718.770
#
#     82  394517.524    9935.250     703.290
#
#     83  395607.018    8619.200     688.820
#
#     84  396674.827    7477.550     675.150
#
#     85  397722.140    6487.100     662.180
#
#     86  398750.073    5627.800     649.890
#
#     87  399759.796    4882.350     638.405
#
#     88  400752.745    4235.650     627.800
#
#     89  401730.253    3674.600     618.035
#
#     90  402693.561    3187.900     609.100
#
#     91  403643.931    2765.600     600.820
#
#     92  404581.473    2399.250     592.735
#
#     93  405506.078    2081.450     584.585
#
#     94  406418.021    1805.750     576.600
#
#     95  407318.499    1566.600     569.425
#
#     96  408209.311    1359.100     563.245
#
#     97  409091.690    1179.050     557.800
#
#     98  409966.316    1022.860     552.940
#
#     99  410833.448     887.385     548.300
#
#    100  411693.484     769.845     543.770
#
#    101  412546.752     667.870     539.470
#
#    102  413393.570     579.405     535.405
#
#    103  414234.281     502.660     531.560
#
#    104  415069.035     436.080     527.790
#
#    105  415897.514     378.315     523.785
#
#    106  416719.070     328.205     519.450
#
#    107  417533.259     284.735     514.820
#
#    108  418339.564     247.020     509.800
#
#    109  419137.473     214.300     504.480
#
#    110  419927.204     185.915     499.330
#
#    111  420709.498     161.290     494.630
#
#    112  421484.873     139.925     490.215
#
#    113  422253.534     121.390     485.970
#
#    114  423015.747     105.310     481.885
#
#    115  423771.726      91.360     477.945
#
#    116  424521.542      79.260     474.140
#
#    117  425265.757      68.760     470.455
#
#    118  426004.360      59.650     466.880
#
#    119  426737.218      51.750     463.425
#
#    120  427464.970      44.895     460.100
#
#    121  428187.383      38.950     456.910
#
#    122  428905.401      33.790     453.865
#
#    123  429618.488      29.315     450.990
#
#    124  430327.021      25.435     448.310
#
#    125  431032.395      22.065     445.855
#
#    126  431734.791      19.140     443.690
#
#
#
#  level          zl          pl
#
#                (m)        (Pa)
#
#      1       0.000************
#
#      2   10685.621************
#
#      3   21222.706************
#
#      4   31608.703************
#
#      5   41841.157************
#
#      6   51917.712************
#
#      7   61836.123************
#
#      8   71594.265************
#
#      9   81190.135************
#
#     10   90621.867************
#
#     11   99887.733************
#
#     12  108986.151************
#
#     13  117915.694************
#
#     14  126675.090************
#
#     15  135263.233************
#
#     16  143679.184************
#
#     17  151922.175************
#
#     18  159991.61494687513.222
#
#     19  167887.08482146002.540
#
#     20  175608.34971265634.758
#
#     21  183155.35261826388.873
#
#     22  190528.21453637386.014
#
#     23  197727.24046533029.519
#
#     24  204752.90940369656.262
#
#     25  211605.87935022631.528
#
#     26  218286.97930383828.665
#
#     27  224797.21126359442.568
#
#     28  231137.74222868092.766
#
#     29  237309.90019839177.760
#
#     30  243315.17117211447.331
#
#     31  249155.18914931763.947
#
#     32  254831.73412954028.228
#
#     33  260346.72411238246.729
#
#     34  265702.205 9749723.199
#
#     35  270900.350 8458356.962
#
#     36  275943.443 7338034.223
#
#     37  280833.877 6366100.000
#
#     38  285583.702 5522900.000
#
#     39  290198.470 4791300.000
#
#     40  294678.178 4156700.000
#
#     41  299025.401 3606100.000
#
#     42  303238.589 3128400.000
#
#     43  307321.618 2714000.000
#
#     44  311275.176 2354500.000
#
#     45  315100.565 2042700.000
#
#     46  318802.106 1772100.000
#
#     47  322379.140 1537400.000
#
#     48  325835.983 1333700.000
#
#     49  329171.972 1157100.000
#
#     50  332393.666 1003800.000
#
#     51  335501.399  870840.000
#
#     52  338498.641  755490.000
#
#     53  341435.449  655420.000
#
#     54  344318.593  568600.000
#
#     55  347137.749  493290.000
#
#     56  349884.040  427950.000
#
#     57  352535.200  371260.000
#
#     58  355039.477  322080.000
#
#     59  357415.751  279420.000
#
#     60  359693.970  242410.000
#
#     61  361885.578  210300.000
#
#     62  363992.717  182440.000
#
#     63  366017.013  158280.000
#
#     64  367962.799  137310.000
#
#     65  369846.581  119120.000
#
#     66  371664.355  103350.000
#
#     67  373418.547   89657.000
#
#     68  375110.938   77781.000
#
#     69  376746.554   67478.000
#
#     70  378326.640   58540.000
#
#     71  379854.252   50786.000
#
#     72  381331.926   44059.000
#
#     73  382762.632   38223.000
#
#     74  384149.277   33160.000
#
#     75  385494.765   28768.000
#
#     76  386802.196   24957.000
#
#     77  388073.510   21651.000
#
#     78  389311.007   18783.000
#
#     79  390517.006   16295.000
#
#     80  391693.582   14137.000
#
#     81  392843.403   12264.000
#
#     82  393967.183   10640.000
#
#     83  395067.865    9230.500
#
#     84  396146.171    8007.900
#
#     85  397203.482    6947.200
#
#     86  398240.797    6027.000
#
#     87  399259.349    5228.600
#
#     88  400260.244    4536.100
#
#     89  401245.246    3935.200
#
#     90  402215.259    3414.000
#
#     91  403171.862    2961.800
#
#     92  404115.999    2569.400
#
#     93  405046.946    2229.100
#
#     94  405965.211    1933.800
#
#     95  406870.832    1677.700
#
#     96  407766.167    1455.500
#
#     97  408652.455    1262.700
#
#     98  409530.925    1095.400
#
#     99  410401.706     950.320
#
#    100  411265.189     824.450
#
#    101  412121.779     715.240
#
#    102  412971.725     620.500
#
#    103  413815.415     538.310
#
#    104  414653.147     467.010
#
#    105  415484.923     405.150
#
#    106  416310.105     351.480
#
#    107  417128.035     304.930
#
#    108  417938.484     264.540
#
#    109  418740.645     229.500
#
#    110  419534.301     199.100
#
#    111  420320.106     172.730
#
#    112  421098.890     149.850
#
#    113  421870.855     130.000
#
#    114  422636.213     112.780
#
#    115  423395.280      97.840
#
#    116  424148.172      84.880
#
#    117  424894.912      73.640
#
#    118  425636.601      63.880
#
#    119  426372.118      55.420
#
#    120  427102.318      48.080
#
#    121  427827.623      41.710
#
#    122  428547.144      36.190
#
#    123  429263.659      31.390
#
#    124  429973.316      27.240
#
#    125  430680.725      23.630
#
#    126  431384.066      20.500
#
#    127  432085.516      17.780
#
#
#
#  istep, time           1   0.0000000000000000      my_first_carma
#
#  istep, time           2   100.00000000000000      my_first_carma
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  WARNING: In microfast
#
#  istep, time           3   200.00000000000000      my_first_carma
#
#  istep, time           4   300.00000000000000      my_first_carma
#
#  istep, time           5   400.00000000000000      my_first_carma
#
#  istep, time           6   500.00000000000000      my_first_carma
#
#  istep, time           7   600.00000000000000      my_first_carma
#
#  istep, time           8   700.00000000000000      my_first_carma
#
#  istep, time           9   800.00000000000000      my_first_carma
#
#  istep, time          10   900.00000000000000      my_first_carma
#
#  istep, time          11   1000.0000000000000      my_first_carma
#
#  istep, time          12   1100.0000000000000      my_first_carma
#
#  istep, time          13   1200.0000000000000      my_first_carma
#
#  istep, time          14   1300.0000000000000      my_first_carma
#
#  istep, time          15   1400.0000000000000      my_first_carma
#
#  istep, time          16   1500.0000000000000      my_first_carma
#
#  istep, time          17   1600.0000000000000      my_first_carma
#
#  istep, time          18   1700.0000000000000      my_first_carma
#
#  istep, time          19   1800.0000000000000      my_first_carma
#
#  istep, time          20   1900.0000000000000      my_first_carma
#
#  istep, time          21   2000.0000000000000      my_first_carma
#
#  istep, time          22   2100.0000000000000      my_first_carma
#
#  istep, time          23   2200.0000000000000      my_first_carma
#
#  istep, time          24   2300.0000000000000      my_first_carma
#
#  istep, time          25   2400.0000000000000      my_first_carma
#
#  istep, time          26   2500.0000000000000      my_first_carma
#
#  istep, time          27   2600.0000000000000      my_first_carma
#
#  istep, time          28   2700.0000000000000      my_first_carma
#
#  istep, time          29   2800.0000000000000      my_first_carma
#
#  istep, time          30   2900.0000000000000      my_first_carma
#
#  istep, time          31   3000.0000000000000      my_first_carma
#
#  istep, time          32   3100.0000000000000      my_first_carma
#
#  istep, time          33   3200.0000000000000      my_first_carma
#
#  istep, time          34   3300.0000000000000      my_first_carma
#
#  istep, time          35   3400.0000000000000      my_first_carma
#
#  istep, time          36   3500.0000000000000      my_first_carma
#
#  istep, time          37   3600.0000000000000      my_first_carma
#
#  istep, time          38   3700.0000000000000      my_first_carma
#
#  istep, time          39   3800.0000000000000      my_first_carma
#
#  istep, time          40   3900.0000000000000      my_first_carma
#
#  istep, time          41   4000.0000000000000      my_first_carma
#
#  istep, time          42   4100.0000000000000      my_first_carma
#
#  istep, time          43   4200.0000000000000      my_first_carma
#
#  istep, time          44   4300.0000000000000      my_first_carma
#
#  istep, time          45   4400.0000000000000      my_first_carma
#
#  istep, time          46   4500.0000000000000      my_first_carma
#
#  istep, time          47   4600.0000000000000      my_first_carma
#
#  istep, time          48   4700.0000000000000      my_first_carma
#
#  istep, time          49   4800.0000000000000      my_first_carma
#
#  istep, time          50   4900.0000000000000      my_first_carma
#
#  istep, time          51   5000.0000000000000      my_first_carma
#
#  istep, time          52   5100.0000000000000      my_first_carma
#
#  istep, time          53   5200.0000000000000      my_first_carma
#
#  istep, time          54   5300.0000000000000      my_first_carma
#
#  istep, time          55   5400.0000000000000      my_first_carma
#
#  istep, time          56   5500.0000000000000      my_first_carma
#
#  istep, time          57   5600.0000000000000      my_first_carma
#
#  istep, time          58   5700.0000000000000      my_first_carma
#
#  istep, time          59   5800.0000000000000      my_first_carma
#
#  istep, time          60   5900.0000000000000      my_first_carma
#
#  istep, time          61   6000.0000000000000      my_first_carma
#
#  istep, time          62   6100.0000000000000      my_first_carma
#
#  istep, time          63   6200.0000000000000      my_first_carma
#
#  istep, time          64   6300.0000000000000      my_first_carma
#
#  istep, time          65   6400.0000000000000      my_first_carma
#
#  istep, time          66   6500.0000000000000      my_first_carma
#
#  istep, time          67   6600.0000000000000      my_first_carma
#
#  istep, time          68   6700.0000000000000      my_first_carma
#
#  istep, time          69   6800.0000000000000      my_first_carma
#
#  istep, time          70   6900.0000000000000      my_first_carma
#
#  istep, time          71   7000.0000000000000      my_first_carma
#
#  istep, time          72   7100.0000000000000      my_first_carma
#
#  istep, time          73   7200.0000000000000      my_first_carma
#
#  istep, time          74   7300.0000000000000      my_first_carma
#
#  istep, time          75   7400.0000000000000      my_first_carma
#
#  istep, time          76   7500.0000000000000      my_first_carma
#
#  istep, time          77   7600.0000000000000      my_first_carma
#
#  istep, time          78   7700.0000000000000      my_first_carma
#
#  istep, time          79   7800.0000000000000      my_first_carma
#
#  istep, time          80   7900.0000000000000      my_first_carma
#
#  istep, time          81   8000.0000000000000      my_first_carma
#
#  istep, time          82   8100.0000000000000      my_first_carma
#
#  istep, time          83   8200.0000000000000      my_first_carma
#
#  istep, time          84   8300.0000000000000      my_first_carma
#
#  istep, time          85   8400.0000000000000      my_first_carma
#
#  istep, time          86   8500.0000000000000      my_first_carma
#
#  istep, time          87   8600.0000000000000      my_first_carma
#
#  istep, time          88   8700.0000000000000      my_first_carma
#
#  istep, time          89   8800.0000000000000      my_first_carma
#
#  istep, time          90   8900.0000000000000      my_first_carma
#
#  istep, time          91   9000.0000000000000      my_first_carma
#
#  istep, time          92   9100.0000000000000      my_first_carma
#
#  istep, time          93   9200.0000000000000      my_first_carma
#
#  istep, time          94   9300.0000000000000      my_first_carma
#
#  istep, time          95   9400.0000000000000      my_first_carma
#
#  istep, time          96   9500.0000000000000      my_first_carma
#
#  istep, time          97   9600.0000000000000      my_first_carma
#
#  istep, time          98   9700.0000000000000      my_first_carma
#
#  istep, time          99   9800.0000000000000      my_first_carma
#
#  istep, time         100   9900.0000000000000      my_first_carma
#
#  istep, time         101   10000.000000000000      my_first_carma
#
#  istep, time         102   10100.000000000000      my_first_carma
#
#  istep, time         103   10200.000000000000      my_first_carma
#
#  istep, time         104   10300.000000000000      my_first_carma
#
#  istep, time         105   10400.000000000000      my_first_carma
#
#  istep, time         106   10500.000000000000      my_first_carma
#
#  istep, time         107   10600.000000000000      my_first_carma
#
#  istep, time         108   10700.000000000000      my_first_carma
#
#  istep, time         109   10800.000000000000      my_first_carma
#
#  istep, time         110   10900.000000000000      my_first_carma
#
#  istep, time         111   11000.000000000000      my_first_carma
#
#  istep, time         112   11100.000000000000      my_first_carma
#
#  istep, time         113   11200.000000000000      my_first_carma
#
#  istep, time         114   11300.000000000000      my_first_carma
#
#  istep, time         115   11400.000000000000      my_first_carma
#
#  istep, time         116   11500.000000000000      my_first_carma
#
#  istep, time         117   11600.000000000000      my_first_carma
#
#  istep, time         118   11700.000000000000      my_first_carma
#
#  istep, time         119   11800.000000000000      my_first_carma
#
#  istep, time         120   11900.000000000000      my_first_carma
#
#  istep, time         121   12000.000000000000      my_first_carma
#
#  istep, time         122   12100.000000000000      my_first_carma
#
#  istep, time         123   12200.000000000000      my_first_carma
#
#  istep, time         124   12300.000000000000      my_first_carma
#
#  istep, time         125   12400.000000000000      my_first_carma
#
#  istep, time         126   12500.000000000000      my_first_carma
#
#  istep, time         127   12600.000000000000      my_first_carma
#
#  istep, time         128   12700.000000000000      my_first_carma
#
#  istep, time         129   12800.000000000000      my_first_carma
#
#  istep, time         130   12900.000000000000      my_first_carma
#
#  istep, time         131   13000.000000000000      my_first_carma
#
#  istep, time         132   13100.000000000000      my_first_carma
#
#  istep, time         133   13200.000000000000      my_first_carma
#
#  istep, time         134   13300.000000000000      my_first_carma
#
#  istep, time         135   13400.000000000000      my_first_carma
#
#  istep, time         136   13500.000000000000      my_first_carma
#
#  istep, time         137   13600.000000000000      my_first_carma
#
#  istep, time         138   13700.000000000000      my_first_carma
#
#  istep, time         139   13800.000000000000      my_first_carma
#
#  istep, time         140   13900.000000000000      my_first_carma
#
#  istep, time         141   14000.000000000000      my_first_carma
#
#  istep, time         142   14100.000000000000      my_first_carma
#
#  istep, time         143   14200.000000000000      my_first_carma
#
#  istep, time         144   14300.000000000000      my_first_carma
#
#  istep, time         145   14400.000000000000      my_first_carma
#
#  istep, time         146   14500.000000000000      my_first_carma
#
#  istep, time         147   14600.000000000000      my_first_carma
#
#  istep, time         148   14700.000000000000      my_first_carma
#
#  istep, time         149   14800.000000000000      my_first_carma
#
#  istep, time         150   14900.000000000000      my_first_carma
#
#  istep, time         151   15000.000000000000      my_first_carma
#
#  istep, time         152   15100.000000000000      my_first_carma
#
#  istep, time         153   15200.000000000000      my_first_carma
#
#  istep, time         154   15300.000000000000      my_first_carma
#
#  istep, time         155   15400.000000000000      my_first_carma
#
#  istep, time         156   15500.000000000000      my_first_carma
#
#  istep, time         157   15600.000000000000      my_first_carma
#
#  istep, time         158   15700.000000000000      my_first_carma
#
#  istep, time         159   15800.000000000000      my_first_carma
#
#  istep, time         160   15900.000000000000      my_first_carma
#
#  istep, time         161   16000.000000000000      my_first_carma
#
#  istep, time         162   16100.000000000000      my_first_carma
#
#  istep, time         163   16200.000000000000      my_first_carma
#
#  istep, time         164   16300.000000000000      my_first_carma
#
#  istep, time         165   16400.000000000000      my_first_carma
#
#  istep, time         166   16500.000000000000      my_first_carma
#
#  istep, time         167   16600.000000000000      my_first_carma
#
#  istep, time         168   16700.000000000000      my_first_carma
#
#  istep, time         169   16800.000000000000      my_first_carma
#
#  istep, time         170   16900.000000000000      my_first_carma
#
#  istep, time         171   17000.000000000000      my_first_carma
#
#  istep, time         172   17100.000000000000      my_first_carma
#
#  istep, time         173   17200.000000000000      my_first_carma
#
#  istep, time         174   17300.000000000000      my_first_carma
#
#  istep, time         175   17400.000000000000      my_first_carma
#
#  istep, time         176   17500.000000000000      my_first_carma
#
#  istep, time         177   17600.000000000000      my_first_carma
#
#  istep, time         178   17700.000000000000      my_first_carma
#
#  istep, time         179   17800.000000000000      my_first_carma
#
#  istep, time         180   17900.000000000000      my_first_carma
#
#  istep, time         181   18000.000000000000      my_first_carma
#
#  istep, time         182   18100.000000000000      my_first_carma
#
#  istep, time         183   18200.000000000000      my_first_carma
#
#  istep, time         184   18300.000000000000      my_first_carma
#
#  istep, time         185   18400.000000000000      my_first_carma
#
#  istep, time         186   18500.000000000000      my_first_carma
#
#  istep, time         187   18600.000000000000      my_first_carma
#
#  istep, time         188   18700.000000000000      my_first_carma
#
#  istep, time         189   18800.000000000000      my_first_carma
#
#  istep, time         190   18900.000000000000      my_first_carma
#
#  istep, time         191   19000.000000000000      my_first_carma
#
#  istep, time         192   19100.000000000000      my_first_carma
#
#  istep, time         193   19200.000000000000      my_first_carma
#
#  istep, time         194   19300.000000000000      my_first_carma
#
#  istep, time         195   19400.000000000000      my_first_carma
#
#  istep, time         196   19500.000000000000      my_first_carma
#
#  istep, time         197   19600.000000000000      my_first_carma
#
#  istep, time         198   19700.000000000000      my_first_carma
#
#  istep, time         199   19800.000000000000      my_first_carma
#
#  istep, time         200   19900.000000000000      my_first_carma
#
#  istep, time         201   20000.000000000000      my_first_carma
#
#  istep, time         202   20100.000000000000      my_first_carma
#
#  istep, time         203   20200.000000000000      my_first_carma
#
#  istep, time         204   20300.000000000000      my_first_carma
#
#  istep, time         205   20400.000000000000      my_first_carma
#
#  istep, time         206   20500.000000000000      my_first_carma
#
#  istep, time         207   20600.000000000000      my_first_carma
#
# ...
#
#  istep, time       23764   2376300.0000000000      my_first_carma
#
#  istep, time       23765   2376400.0000000000      my_first_carma
#
#  istep, time       23766   2376500.0000000000      my_first_carma
#
#  istep, time       23767   2376600.0000000000      my_first_carma
#
#  istep, time       23768   2376700.0000000000      my_first_carma
#
#  istep, time       23769   2376800.0000000000      my_first_carma
#
#  istep, time       23770   2376900.0000000000      my_first_carma
#
#  istep, time       23771   2377000.0000000000      my_first_carma
#
#  istep, time       23772   2377100.0000000000      my_first_carma
#
#  istep, time       23773   2377200.0000000000      my_first_carma
#
#  istep, time       23774   2377300.0000000000      my_first_carma
#
#  istep, time       23775   2377400.0000000000      my_first_carma
#
#  istep, time       23776   2377500.0000000000      my_first_carma
#
#  istep, time       23777   2377600.0000000000      my_first_carma
#
#  istep, time       23778   2377700.0000000000      my_first_carma
#
#  istep, time       23779   2377800.0000000000      my_first_carma
#
#  istep, time       23780   2377900.0000000000      my_first_carma
#
#  istep, time       23781   2378000.0000000000      my_first_carma
#
#  istep, time       23782   2378100.0000000000      my_first_carma
#
#  istep, time       23783   2378200.0000000000      my_first_carma
#
#  istep, time       23784   2378300.0000000000      my_first_carma
#
#  istep, time       23785   2378400.0000000000      my_first_carma
#
#  istep, time       23786   2378500.0000000000      my_first_carma
#
#  istep, time       23787   2378600.0000000000      my_first_carma
#
#  istep, time       23788   2378700.0000000000      my_first_carma
#
#  istep, time       23789   2378800.0000000000      my_first_carma
#
#  istep, time       23790   2378900.0000000000      my_first_carma
#
#  istep, time       23791   2379000.0000000000      my_first_carma
#
#  istep, time       23792   2379100.0000000000      my_first_carma
#
#  istep, time       23793   2379200.0000000000      my_first_carma
#
#  istep, time       23794   2379300.0000000000      my_first_carma
#
#  istep, time       23795   2379400.0000000000      my_first_carma
#
#  istep, time       23796   2379500.0000000000      my_first_carma
#
#  istep, time       23797   2379600.0000000000      my_first_carma
#
#  istep, time       23798   2379700.0000000000      my_first_carma
#
#  istep, time       23799   2379800.0000000000      my_first_carma
#
#  istep, time       23800   2379900.0000000000      my_first_carma
#
#  istep, time       23801   2380000.0000000000      my_first_carma
#
#  istep, time       23802   2380100.0000000000      my_first_carma
#
#  istep, time       23803   2380200.0000000000      my_first_carma
#
#  istep, time       23804   2380300.0000000000      my_first_carma
#
#  istep, time       23805   2380400.0000000000      my_first_carma
#
#  istep, time       23806   2380500.0000000000      my_first_carma
#
#  istep, time       23807   2380600.0000000000      my_first_carma
#
#  istep, time       23808   2380700.0000000000      my_first_carma
#
#  istep, time       23809   2380800.0000000000      my_first_carma
#
#  istep, time       23810   2380900.0000000000      my_first_carma
#
#  istep, time       23811   2381000.0000000000      my_first_carma
#
#  istep, time       23812   2381100.0000000000      my_first_carma
#
#  istep, time       23813   2381200.0000000000      my_first_carma
#
#  istep, time       23814   2381300.0000000000      my_first_carma
#
#  istep, time       23815   2381400.0000000000      my_first_carma
#
#  istep, time       23816   2381500.0000000000      my_first_carma
#
#  istep, time       23817   2381600.0000000000      my_first_carma
#
#  istep, time       23818   2381700.0000000000      my_first_carma
#
#  istep, time       23819   2381800.0000000000      my_first_carma
#
#  istep, time       23820   2381900.0000000000      my_first_carma
#
#  istep, time       23821   2382000.0000000000      my_first_carma
#
#  istep, time       23822   2382100.0000000000      my_first_carma
#
#  istep, time       23823   2382200.0000000000      my_first_carma
#
#  istep, time       23824   2382300.0000000000      my_first_carma
#
#  istep, time       23825   2382400.0000000000      my_first_carma
#
#  istep, time       23826   2382500.0000000000      my_first_carma
#
#  istep, time       23827   2382600.0000000000      my_first_carma
#
#  istep, time       23828   2382700.0000000000      my_first_carma
#
#  istep, time       23829   2382800.0000000000      my_first_carma
#
#  istep, time       23830   2382900.0000000000      my_first_carma
#
#  istep, time       23831   2383000.0000000000      my_first_carma
#
#  istep, time       23832   2383100.0000000000      my_first_carma
#
#  istep, time       23833   2383200.0000000000      my_first_carma
#
#  istep, time       23834   2383300.0000000000      my_first_carma
#
#  istep, time       23835   2383400.0000000000      my_first_carma
#
#  istep, time       23836   2383500.0000000000      my_first_carma
#
#  istep, time       23837   2383600.0000000000      my_first_carma
#
#  istep, time       23838   2383700.0000000000      my_first_carma
#
#  istep, time       23839   2383800.0000000000      my_first_carma
#
#  istep, time       23840   2383900.0000000000      my_first_carma
#
#  istep, time       23841   2384000.0000000000      my_first_carma
#
#  istep, time       23842   2384100.0000000000      my_first_carma
#
#  istep, time       23843   2384200.0000000000      my_first_carma
#
#  istep, time       23844   2384300.0000000000      my_first_carma
#
#  istep, time       23845   2384400.0000000000      my_first_carma
#
#  istep, time       23846   2384500.0000000000      my_first_carma
#
#  istep, time       23847   2384600.0000000000      my_first_carma
#
#  istep, time       23848   2384700.0000000000      my_first_carma
#
#  istep, time       23849   2384800.0000000000      my_first_carma
#
#  istep, time       23850   2384900.0000000000      my_first_carma
#
#  istep, time       23851   2385000.0000000000      my_first_carma
#
#  istep, time       23852   2385100.0000000000      my_first_carma
#
#  istep, time       23853   2385200.0000000000      my_first_carma
#
#  istep, time       23854   2385300.0000000000      my_first_carma
#
#  istep, time       23855   2385400.0000000000      my_first_carma
#
#  istep, time       23856   2385500.0000000000      my_first_carma
#
#  istep, time       23857   2385600.0000000000      my_first_carma
#
#  istep, time       23858   2385700.0000000000      my_first_carma
#
#  istep, time       23859   2385800.0000000000      my_first_carma
#
#  istep, time       23860   2385900.0000000000      my_first_carma
#
#  istep, time       23861   2386000.0000000000      my_first_carma
#
#  istep, time       23862   2386100.0000000000      my_first_carma
#
#  istep, time       23863   2386200.0000000000      my_first_carma
#
#  istep, time       23864   2386300.0000000000      my_first_carma
#
#  istep, time       23865   2386400.0000000000      my_first_carma
#
#  istep, time       23866   2386500.0000000000      my_first_carma
#
#  istep, time       23867   2386600.0000000000      my_first_carma
#
#  istep, time       23868   2386700.0000000000      my_first_carma
#
#  istep, time       23869   2386800.0000000000      my_first_carma
#
#  istep, time       23870   2386900.0000000000      my_first_carma
#
#  istep, time       23871   2387000.0000000000      my_first_carma
#
#  istep, time       23872   2387100.0000000000      my_first_carma
#
#  istep, time       23873   2387200.0000000000      my_first_carma
#
#  istep, time       23874   2387300.0000000000      my_first_carma
#
#  istep, time       23875   2387400.0000000000      my_first_carma
#
#  istep, time       23876   2387500.0000000000      my_first_carma
#
#  istep, time       23877   2387600.0000000000      my_first_carma
#
#  istep, time       23878   2387700.0000000000      my_first_carma
#
#  istep, time       23879   2387800.0000000000      my_first_carma
#
#  istep, time       23880   2387900.0000000000      my_first_carma
#
#  istep, time       23881   2388000.0000000000      my_first_carma
#
#  istep, time       23882   2388100.0000000000      my_first_carma
#
#  istep, time       23883   2388200.0000000000      my_first_carma
#
#  istep, time       23884   2388300.0000000000      my_first_carma
#
#  istep, time       23885   2388400.0000000000      my_first_carma
#
#  istep, time       23886   2388500.0000000000      my_first_carma
#
#  istep, time       23887   2388600.0000000000      my_first_carma
#
#  istep, time       23888   2388700.0000000000      my_first_carma
#
#  istep, time       23889   2388800.0000000000      my_first_carma
#
#  istep, time       23890   2388900.0000000000      my_first_carma
#
#  istep, time       23891   2389000.0000000000      my_first_carma
#
#  istep, time       23892   2389100.0000000000      my_first_carma
#
#  istep, time       23893   2389200.0000000000      my_first_carma
#
#  istep, time       23894   2389300.0000000000      my_first_carma
#
#  istep, time       23895   2389400.0000000000      my_first_carma
#
#  istep, time       23896   2389500.0000000000      my_first_carma
#
#  istep, time       23897   2389600.0000000000      my_first_carma
#
#  istep, time       23898   2389700.0000000000      my_first_carma
#
#  istep, time       23899   2389800.0000000000      my_first_carma
#
#  istep, time       23900   2389900.0000000000      my_first_carma
#
#  istep, time       23901   2390000.0000000000      my_first_carma
#
#  istep, time       23902   2390100.0000000000      my_first_carma
#
#  istep, time       23903   2390200.0000000000      my_first_carma
#
#  istep, time       23904   2390300.0000000000      my_first_carma
#
#  istep, time       23905   2390400.0000000000      my_first_carma
#
#  istep, time       23906   2390500.0000000000      my_first_carma
#
#  istep, time       23907   2390600.0000000000      my_first_carma
#
#  istep, time       23908   2390700.0000000000      my_first_carma
#
#  istep, time       23909   2390800.0000000000      my_first_carma
#
#  istep, time       23910   2390900.0000000000      my_first_carma
#
#  istep, time       23911   2391000.0000000000      my_first_carma
#
#  istep, time       23912   2391100.0000000000      my_first_carma
#
#  istep, time       23913   2391200.0000000000      my_first_carma
#
#  istep, time       23914   2391300.0000000000      my_first_carma
#
#  istep, time       23915   2391400.0000000000      my_first_carma
#
#  istep, time       23916   2391500.0000000000      my_first_carma
#
#  istep, time       23917   2391600.0000000000      my_first_carma
#
#  istep, time       23918   2391700.0000000000      my_first_carma
#
#  istep, time       23919   2391800.0000000000      my_first_carma
#
#  istep, time       23920   2391900.0000000000      my_first_carma
#
#  istep, time       23921   2392000.0000000000      my_first_carma
#
#  istep, time       23922   2392100.0000000000      my_first_carma
#
#  istep, time       23923   2392200.0000000000      my_first_carma
#
#  istep, time       23924   2392300.0000000000      my_first_carma
#
#  istep, time       23925   2392400.0000000000      my_first_carma
#
#  istep, time       23926   2392500.0000000000      my_first_carma
#
#  istep, time       23927   2392600.0000000000      my_first_carma
#
#  istep, time       23928   2392700.0000000000      my_first_carma
#
#  istep, time       23929   2392800.0000000000      my_first_carma
#
#  istep, time       23930   2392900.0000000000      my_first_carma
#
#  istep, time       23931   2393000.0000000000      my_first_carma
#
#  istep, time       23932   2393100.0000000000      my_first_carma
#
#  istep, time       23933   2393200.0000000000      my_first_carma
#
#  istep, time       23934   2393300.0000000000      my_first_carma
#
#  istep, time       23935   2393400.0000000000      my_first_carma
#
#  istep, time       23936   2393500.0000000000      my_first_carma
#
#  istep, time       23937   2393600.0000000000      my_first_carma
#
#  istep, time       23938   2393700.0000000000      my_first_carma
#
#  istep, time       23939   2393800.0000000000      my_first_carma
#
#  istep, time       23940   2393900.0000000000      my_first_carma
#
#  istep, time       23941   2394000.0000000000      my_first_carma
#
#  istep, time       23942   2394100.0000000000      my_first_carma
#
#  istep, time       23943   2394200.0000000000      my_first_carma
#
#  istep, time       23944   2394300.0000000000      my_first_carma
#
#  istep, time       23945   2394400.0000000000      my_first_carma
#
#  istep, time       23946   2394500.0000000000      my_first_carma
#
#  istep, time       23947   2394600.0000000000      my_first_carma
#
#  istep, time       23948   2394700.0000000000      my_first_carma
#
#  istep, time       23949   2394800.0000000000      my_first_carma
#
#  istep, time       23950   2394900.0000000000      my_first_carma
#
#  istep, time       23951   2395000.0000000000      my_first_carma
#
#  istep, time       23952   2395100.0000000000      my_first_carma
#
#  istep, time       23953   2395200.0000000000      my_first_carma
#
#  istep, time       23954   2395300.0000000000      my_first_carma
#
#  istep, time       23955   2395400.0000000000      my_first_carma
#
#  istep, time       23956   2395500.0000000000      my_first_carma
#
#  istep, time       23957   2395600.0000000000      my_first_carma
#
#  istep, time       23958   2395700.0000000000      my_first_carma
#
#  istep, time       23959   2395800.0000000000      my_first_carma
#
#  istep, time       23960   2395900.0000000000      my_first_carma
#
#  istep, time       23961   2396000.0000000000      my_first_carma
#
#  istep, time       23962   2396100.0000000000      my_first_carma
#
#  istep, time       23963   2396200.0000000000      my_first_carma
#
#  istep, time       23964   2396300.0000000000      my_first_carma
#
#  istep, time       23965   2396400.0000000000      my_first_carma
#
#  istep, time       23966   2396500.0000000000      my_first_carma
#
#  istep, time       23967   2396600.0000000000      my_first_carma
#
#  istep, time       23968   2396700.0000000000      my_first_carma
#
#  istep, time       23969   2396800.0000000000      my_first_carma
#
#  istep, time       23970   2396900.0000000000      my_first_carma
#
#  istep, time       23971   2397000.0000000000      my_first_carma
#
#  istep, time       23972   2397100.0000000000      my_first_carma
#
#  istep, time       23973   2397200.0000000000      my_first_carma
#
#  istep, time       23974   2397300.0000000000      my_first_carma
#
#  istep, time       23975   2397400.0000000000      my_first_carma
#
#  istep, time       23976   2397500.0000000000      my_first_carma
#
#  istep, time       23977   2397600.0000000000      my_first_carma
#
#  istep, time       23978   2397700.0000000000      my_first_carma
#
#  istep, time       23979   2397800.0000000000      my_first_carma
#
#  istep, time       23980   2397900.0000000000      my_first_carma
#
#  istep, time       23981   2398000.0000000000      my_first_carma
#
#  istep, time       23982   2398100.0000000000      my_first_carma
#
#  istep, time       23983   2398200.0000000000      my_first_carma
#
#  istep, time       23984   2398300.0000000000      my_first_carma
#
#  istep, time       23985   2398400.0000000000      my_first_carma
#
#  istep, time       23986   2398500.0000000000      my_first_carma
#
#  istep, time       23987   2398600.0000000000      my_first_carma
#
#  istep, time       23988   2398700.0000000000      my_first_carma
#
#  istep, time       23989   2398800.0000000000      my_first_carma
#
#  istep, time       23990   2398900.0000000000      my_first_carma
#
#  istep, time       23991   2399000.0000000000      my_first_carma
#
#  istep, time       23992   2399100.0000000000      my_first_carma
#
#  istep, time       23993   2399200.0000000000      my_first_carma
#
#  istep, time       23994   2399300.0000000000      my_first_carma
#
#  istep, time       23995   2399400.0000000000      my_first_carma
#
#  istep, time       23996   2399500.0000000000      my_first_carma
#
#  istep, time       23997   2399600.0000000000      my_first_carma
#
#  istep, time       23998   2399700.0000000000      my_first_carma
#
#  istep, time       23999   2399800.0000000000      my_first_carma
#
#  istep, time       24000   2399900.0000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#
#
#  CARMA_Destroy() ...
#
#  Done

# %% [markdown]
# Note that when you call `carma.run()` a directory with the name `"my_first_carma"` (or whatever you set the name of your carma object as) should have been created.  The directory stores the state of the model along with the model output—do not move or delete it while the model is running.  The next tutorial will go over how to read the output from that directory.
