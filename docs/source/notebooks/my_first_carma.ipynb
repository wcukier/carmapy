# %% [markdown]
# # My First Carma Object Model
#
# We are going to start by importing carmapy and creating a carma object.  Each carma object has a name that corresponds with a path to a directory that will be created upon running the model to house the model and its output—we will name this carma object "my_first_carma"

# %%
import carmapy

carma = carmapy.Carma("my_first_carma")

# %% [markdown]
# ## Setting Time Steps
#
# We will now tell carmapy its timestep, along with how often to output data, and how many timesteps to run

# %%
carma.set_stepping(dt=250, output_gap=10, n_tstep=100)

# %% [markdown]
# The parameters tell carmapy the following
#  - `dt` is the time step, in seconds
#  - `output_gap` is the number of time steps between each time the CARMA simulation writes to file
#  - `n_tstep` is the total number of timesteps to run CARMA for

# %% [markdown]
# ## Setting Atmospheric Structure and Physical Parameters
#
# For this example we will use the example atmopsheric structure that is included in carmapy but you of course can provide your own.  This atmospheric structure comes from a sonora diamondback ([Morley et al. 2024](https://doi.org/10.48550/arXiv.2402.00758)) run of a 1000 K solar-metalicity brown dwarf with a surface gravity of 31,600 cm/s² ($f_\text{sed} = 4$)

# %%
P_levs, T_levs, kzz_levs, mu_levs = carmapy.example.example_levels()

carma.add_P(P_levs)
carma.add_T(T_levs)
carma.add_kzz(kzz_levs)

# %% [markdown]
# Note that all of the inputs to carmapy are in cgs units so the units of `P_levs` is baryes, `T_levs` is in K, and `kzz_levs` is in cm²/s.  Each of these arrays are "levels" arrays which mean they describe the atmosphere at the boundary between layers—carmapy will model the formation of clouds at the "centers" location, between each of the provided "levels" locations.  Thus, if you want $N$ locations vertically where clouds might form, your "levels" arrays must be $N+1$ elements long.
#
# We also need to specify the surface gravity and the mean molecular weight of the atmosphere.  While our mean molecular weight varies throughout the atmosphere, carmapy requires a single value of the mean molecular weight to represent the entire atmosphere—in this case we will use the mean molecular weight at the bottom of the atmosphere

# %%
carma.set_physical_params(surface_grav=31600,
                            wt_mol=mu_levs[0])

# %% [markdown]
# Here we set the surface gravity to 31,600 cm/s² using the `surface_grav` argument and the mean molecular weight to the mean molecular weight at the bottom of our atmosphere using the `wt_mol` argument.
#
# Since we do not have altitude levels, we can tell carmapy to calculate the altitudes for us.

# %%
carma.calculate_z()

# %% [markdown]
# Since we have them, we can instead optionally use the complete mean molecular weight profile of our atmosphere for added accuracy:

# %%
carma.calculate_z(mu_levs)

# %% [markdown]
# For more accurate cloud calculations, sometimes we need deeper atmospheres than those commonly provided by evolutionary codes.  In those cases, we can tell carmapy to extend the bottom of the atmosphere adiabatically to a deeper pressure.

# %%
carma.extend_atmosphere(1e10)

# %% [markdown]
# Above we extended the atmosphere to a pressure of $10^{10}$ baryes.

# %% [markdown]
# ## Setting Cloud Physics
#
# carmapy requires that we tell it which species we should let form.  We do so by adding groups—types of particles that can form.  There are two types of groups:
#
# 1. Homogeneous Groups: These groups are particles which form via homogeneous nucleation and thus do not need a seed particle to form
# 2. Heterogeneous Groups: These groups are particles which consist of one specie which heterogeneously nucleated onto another specie, the latter of which serves as a seed particle.
#
# We can add a homogeneous group and then a heterogeneous group that nucleates on the homogeneous group as follows:

# %%
carma.add_hom_group("TiO2", 1e-8)
carma.add_het_group("Mg2SiO4", "TiO2", 1e-8 * 2**(1/3))

# %% [markdown]
# `carma.add_hom_group("TiO2", 1e-8)` tells carmapy to allow TiO₂ to homogeneously condense with a minimum radius of $10^{-8}$ cm using the physical properties of TiO₂ preprogrammed into carmapy (some of these properties can be changed: see the documentation for Elements and Gasses once they are written).
#
# `carma.add_het_group("Mg2SiO4", "TiO2", 1e-8 * 2**(1/3))` similarly tells carmapy to allow Mg₂SiO₄ to heterogeneously condense upon the TiO₂ seed particles in the group above.  This group has a minimum particle radius of $1.41 \times 10^{-8}$ cm.  Note that a homogeneous group must be created before a heterogeneous group can be defined to condense upon it.
#
# Any number of homogeneous and heterogeneous groups can be created, we created only 2 here for simplicity's sake.
#
# Unfortunately due to how CARMA was programmed, we are only able to provide a limited selection of species at this time.  You can see the supported species as follows:

# %%
carmapy.available_species()
# Out:
# ['KCl', 'ZnS', 'Na2S', 'MnS', 'Cr', 'Mg2SiO4', 'Fe', 'TiO2', 'Al2O3']

# %% [markdown]
# Additionally, the interaction term, `mucos`, for heterogeneously nucleating particles is only preprogrammed for certain combinations of species.  To see which species a given specie is able to condense upon without manually specifying `mucos` you can run the following code:

# %%
carmapy.included_mucos("Mg2SiO4")
# Out:
# {'TiO2': 0.995}

# %% [markdown]
# This indicates that Mg₂SiO₄ has an included interaction term for when it heterogeneously nucleates onto TiO₂.  If this term was not included in carmapy or we wanted to explore how the model changes if this interaction term is weaker we could, instead of running the above code to add groups, uncomment and run the below code:

# %%
# carma.add_hom_group("TiO2", 1e-8)
# carma.add_het_group("Mg2SiO4", "TiO2", 1e-8 * 2**(1/3), mucos=0.9)

# %% [markdown]
# ## Atmospheric Composition

# %% [markdown]
# We finaly need to tell carma the gas abundances for each gas resevoir that is limiting for each species.  (The limiting gas for each specie has defaults hard-coded—see the defaults documentation page once it is written).  The most common way to do that is to calculate the gas abundance at the base of each clouds—the place where the saturation vapor pressure for the specie reaches the atmospheric pressure—and consider that the gas mixing ratio of the specie at the bottom of the atmopshere.  Included in carmapy is a helper function which uses [fastchem](https://github.com/newstrangeworlds/fastchem) to calculate the abundances given a metallicity

# %%
carmapy.chemistry.populate_abundances_at_cloud_base(carma, metalicity=1)

# %% [markdown]
# Note that `metallicity` is *not* a log metallicity.  `metallicity=1` corresponds with solar metallicity.

# %% [markdown]
# ## Running the model

# %% [markdown]
# Now the model is setup it is simple to run the model:

# %%
carma.run(suppress_output=True)
# Out:
# /Users/wcukier/miniconda3/lib/python3.12/site-packages
#
#
#  Create CARMA Object ...
#
#
#
#    Add Group(s) ...
#
#
#
#  Add Pure TiO2...
#
#  Add Mg2SiO4 on TiO2...
#
#
#
#    Add Element(s) ...
#
#
#
#  Add Pure TiO2...
#
#  Add Mg2SiO4 Mantle...
#
#  Add TiO2 Core (Mg2SiO4)...
#
#
#
#    Add Solute(s) ...
#
#
#
#  Add H2SO4 Solute ...
#
#
#
#    Add Gas(es) ...
#
#
#
#  Add H2O Vapor ...
#
#            2
#
#  Add TiO2 Vapor ...
#
#           16
#
#  Add Mg2SiO4 Vapor ...
#
#           13
#
#    Add Nucleation ...
#
#    Add Growth ...
#
#    Add Coagulation ...
#
#
#
#  Initialize CARMA ...
#
#
#
# Particle grid structure (setupbins):
#
# NGROUP :       2
#
# NELEM  :       3
#
# NBIN   :      80
#
# Massmin:     1.780E-23   2.689E-23
#
# Mrat   :          2.00        2.00
#
# nelemg :       1     2
#
# itype  :       2     2     3
#
# ienconc:       1     2
#
# igelem :       1     2     2
#
# ncore  :       0     1
#
#
#
#  Nucleation mapping arrays (setupnuc):
#
#
#
#  Elements mapping:
#
#  ielem,nnucelem=           1           1
#
#  jfrom,inucelem=             1           1
#
#  ielem,nnucelem=           2           1
#
#  jfrom,inucelem=             1           1
#
#  ielem,nnucelem=           3           1
#
#  jfrom,inucelem=             1           1
#
#
#
#  Bin mapping:
#
#
#
#  Groups (from, to) =            1           1
#
#    ibin,nnucbin=           1           1
#
#     inucbin=           1
#
#    ibin,nnucbin=           2           1
#
#     inucbin=           2
#
#    ibin,nnucbin=           3           1
#
#     inucbin=           3
#
#    ibin,nnucbin=           4           1
#
#     inucbin=           4
#
#    ibin,nnucbin=           5           1
#
#     inucbin=           5
#
#    ibin,nnucbin=           6           1
#
#     inucbin=           6
#
#    ibin,nnucbin=           7           1
#
#     inucbin=           7
#
#    ibin,nnucbin=           8           1
#
#     inucbin=           8
#
#    ibin,nnucbin=           9           1
#
#     inucbin=           9
#
#    ibin,nnucbin=          10           1
#
#     inucbin=          10
#
#    ibin,nnucbin=          11           1
#
#     inucbin=          11
#
#    ibin,nnucbin=          12           1
#
#     inucbin=          12
#
#    ibin,nnucbin=          13           1
#
#     inucbin=          13
#
#    ibin,nnucbin=          14           1
#
#     inucbin=          14
#
#    ibin,nnucbin=          15           1
#
#     inucbin=          15
#
#    ibin,nnucbin=          16           1
#
#     inucbin=          16
#
#    ibin,nnucbin=          17           1
#
#     inucbin=          17
#
#    ibin,nnucbin=          18           1
#
#     inucbin=          18
#
#    ibin,nnucbin=          19           1
#
#     inucbin=          19
#
#    ibin,nnucbin=          20           1
#
#     inucbin=          20
#
#    ibin,nnucbin=          21           1
#
#     inucbin=          21
#
#    ibin,nnucbin=          22           1
#
#     inucbin=          22
#
#    ibin,nnucbin=          23           1
#
#     inucbin=          23
#
#    ibin,nnucbin=          24           1
#
#     inucbin=          24
#
#    ibin,nnucbin=          25           1
#
#     inucbin=          25
#
#    ibin,nnucbin=          26           1
#
#     inucbin=          26
#
#    ibin,nnucbin=          27           1
#
#     inucbin=          27
#
#    ibin,nnucbin=          28           1
#
#     inucbin=          28
#
#    ibin,nnucbin=          29           1
#
#     inucbin=          29
#
#    ibin,nnucbin=          30           1
#
#     inucbin=          30
#
#    ibin,nnucbin=          31           1
#
#     inucbin=          31
#
#    ibin,nnucbin=          32           1
#
#     inucbin=          32
#
#    ibin,nnucbin=          33           1
#
#     inucbin=          33
#
#    ibin,nnucbin=          34           1
#
#     inucbin=          34
#
#    ibin,nnucbin=          35           1
#
#     inucbin=          35
#
#    ibin,nnucbin=          36           1
#
#     inucbin=          36
#
#    ibin,nnucbin=          37           1
#
#     inucbin=          37
#
#    ibin,nnucbin=          38           1
#
#     inucbin=          38
#
#    ibin,nnucbin=          39           1
#
#     inucbin=          39
#
#    ibin,nnucbin=          40           1
#
#     inucbin=          40
#
#    ibin,nnucbin=          41           1
#
#     inucbin=          41
#
#    ibin,nnucbin=          42           1
#
#     inucbin=          42
#
#    ibin,nnucbin=          43           1
#
#     inucbin=          43
#
#    ibin,nnucbin=          44           1
#
#     inucbin=          44
#
#    ibin,nnucbin=          45           1
#
#     inucbin=          45
#
#    ibin,nnucbin=          46           1
#
#     inucbin=          46
#
#    ibin,nnucbin=          47           1
#
#     inucbin=          47
#
#    ibin,nnucbin=          48           1
#
#     inucbin=          48
#
#    ibin,nnucbin=          49           1
#
#     inucbin=          49
#
#    ibin,nnucbin=          50           1
#
#     inucbin=          50
#
#    ibin,nnucbin=          51           1
#
#     inucbin=          51
#
#    ibin,nnucbin=          52           1
#
#     inucbin=          52
#
#    ibin,nnucbin=          53           1
#
#     inucbin=          53
#
#    ibin,nnucbin=          54           1
#
#     inucbin=          54
#
#    ibin,nnucbin=          55           1
#
#     inucbin=          55
#
#    ibin,nnucbin=          56           1
#
#     inucbin=          56
#
#    ibin,nnucbin=          57           1
#
#     inucbin=          57
#
#    ibin,nnucbin=          58           1
#
#     inucbin=          58
#
#    ibin,nnucbin=          59           1
#
#     inucbin=          59
#
#    ibin,nnucbin=          60           1
#
#     inucbin=          60
#
#    ibin,nnucbin=          61           1
#
#     inucbin=          61
#
#    ibin,nnucbin=          62           1
#
#     inucbin=          62
#
#    ibin,nnucbin=          63           1
#
#     inucbin=          63
#
#    ibin,nnucbin=          64           1
#
#     inucbin=          64
#
#    ibin,nnucbin=          65           1
#
#     inucbin=          65
#
#    ibin,nnucbin=          66           1
#
#     inucbin=          66
#
#    ibin,nnucbin=          67           1
#
#     inucbin=          67
#
#    ibin,nnucbin=          68           1
#
#     inucbin=          68
#
#    ibin,nnucbin=          69           1
#
#     inucbin=          69
#
#    ibin,nnucbin=          70           1
#
#     inucbin=          70
#
#    ibin,nnucbin=          71           1
#
#     inucbin=          71
#
#    ibin,nnucbin=          72           1
#
#     inucbin=          72
#
#    ibin,nnucbin=          73           1
#
#     inucbin=          73
#
#    ibin,nnucbin=          74           1
#
#     inucbin=          74
#
#    ibin,nnucbin=          75           1
#
#     inucbin=          75
#
#    ibin,nnucbin=          76           1
#
#     inucbin=          76
#
#    ibin,nnucbin=          77           1
#
#     inucbin=          77
#
#    ibin,nnucbin=          78           1
#
#     inucbin=          78
#
#    ibin,nnucbin=          79           1
#
#     inucbin=          79
#
#    ibin,nnucbin=          80           1
#
#     inucbin=          80
#
#
#
#  Groups (from, to) =            1           2
#
#    ibin,nnucbin=           1           1
#
#     inucbin=           1
#
#    ibin,nnucbin=           2           1
#
#     inucbin=           2
#
#    ibin,nnucbin=           3           1
#
#     inucbin=           3
#
#    ibin,nnucbin=           4           1
#
#     inucbin=           4
#
#    ibin,nnucbin=           5           1
#
#     inucbin=           5
#
#    ibin,nnucbin=           6           1
#
#     inucbin=           6
#
#    ibin,nnucbin=           7           1
#
#     inucbin=           7
#
#    ibin,nnucbin=           8           1
#
#     inucbin=           8
#
#    ibin,nnucbin=           9           1
#
#     inucbin=           9
#
#    ibin,nnucbin=          10           1
#
#     inucbin=          10
#
#    ibin,nnucbin=          11           1
#
#     inucbin=          11
#
#    ibin,nnucbin=          12           1
#
#     inucbin=          12
#
#    ibin,nnucbin=          13           1
#
#     inucbin=          13
#
#    ibin,nnucbin=          14           1
#
#     inucbin=          14
#
#    ibin,nnucbin=          15           1
#
#     inucbin=          15
#
#    ibin,nnucbin=          16           1
#
#     inucbin=          16
#
#    ibin,nnucbin=          17           1
#
#     inucbin=          17
#
#    ibin,nnucbin=          18           1
#
#     inucbin=          18
#
#    ibin,nnucbin=          19           1
#
#     inucbin=          19
#
#    ibin,nnucbin=          20           1
#
#     inucbin=          20
#
#    ibin,nnucbin=          21           1
#
#     inucbin=          21
#
#    ibin,nnucbin=          22           1
#
#     inucbin=          22
#
#    ibin,nnucbin=          23           1
#
#     inucbin=          23
#
#    ibin,nnucbin=          24           1
#
#     inucbin=          24
#
#    ibin,nnucbin=          25           1
#
#     inucbin=          25
#
#    ibin,nnucbin=          26           1
#
#     inucbin=          26
#
#    ibin,nnucbin=          27           1
#
#     inucbin=          27
#
#    ibin,nnucbin=          28           1
#
#     inucbin=          28
#
#    ibin,nnucbin=          29           1
#
#     inucbin=          29
#
#    ibin,nnucbin=          30           1
#
#     inucbin=          30
#
#    ibin,nnucbin=          31           1
#
#     inucbin=          31
#
#    ibin,nnucbin=          32           1
#
#     inucbin=          32
#
#    ibin,nnucbin=          33           1
#
#     inucbin=          33
#
#    ibin,nnucbin=          34           1
#
#     inucbin=          34
#
#    ibin,nnucbin=          35           1
#
#     inucbin=          35
#
#    ibin,nnucbin=          36           1
#
#     inucbin=          36
#
#    ibin,nnucbin=          37           1
#
#     inucbin=          37
#
#    ibin,nnucbin=          38           1
#
#     inucbin=          38
#
#    ibin,nnucbin=          39           1
#
#     inucbin=          39
#
#    ibin,nnucbin=          40           1
#
#     inucbin=          40
#
#    ibin,nnucbin=          41           1
#
#     inucbin=          41
#
#    ibin,nnucbin=          42           1
#
#     inucbin=          42
#
#    ibin,nnucbin=          43           1
#
#     inucbin=          43
#
#    ibin,nnucbin=          44           1
#
#     inucbin=          44
#
#    ibin,nnucbin=          45           1
#
#     inucbin=          45
#
#    ibin,nnucbin=          46           1
#
#     inucbin=          46
#
#    ibin,nnucbin=          47           1
#
#     inucbin=          47
#
#    ibin,nnucbin=          48           1
#
#     inucbin=          48
#
#    ibin,nnucbin=          49           1
#
#     inucbin=          49
#
#    ibin,nnucbin=          50           1
#
#     inucbin=          50
#
#    ibin,nnucbin=          51           1
#
#     inucbin=          51
#
#    ibin,nnucbin=          52           1
#
#     inucbin=          52
#
#    ibin,nnucbin=          53           1
#
#     inucbin=          53
#
#    ibin,nnucbin=          54           1
#
#     inucbin=          54
#
#    ibin,nnucbin=          55           1
#
#     inucbin=          55
#
#    ibin,nnucbin=          56           1
#
#     inucbin=          56
#
#    ibin,nnucbin=          57           1
#
#     inucbin=          57
#
#    ibin,nnucbin=          58           1
#
#     inucbin=          58
#
#    ibin,nnucbin=          59           1
#
#     inucbin=          59
#
#    ibin,nnucbin=          60           1
#
#     inucbin=          60
#
#    ibin,nnucbin=          61           1
#
#     inucbin=          61
#
#    ibin,nnucbin=          62           1
#
#     inucbin=          62
#
#    ibin,nnucbin=          63           1
#
#     inucbin=          63
#
#    ibin,nnucbin=          64           1
#
#     inucbin=          64
#
#    ibin,nnucbin=          65           1
#
#     inucbin=          65
#
#    ibin,nnucbin=          66           1
#
#     inucbin=          66
#
#    ibin,nnucbin=          67           1
#
#     inucbin=          67
#
#    ibin,nnucbin=          68           1
#
#     inucbin=          68
#
#    ibin,nnucbin=          69           1
#
#     inucbin=          69
#
#    ibin,nnucbin=          70           1
#
#     inucbin=          70
#
#    ibin,nnucbin=          71           1
#
#     inucbin=          71
#
#    ibin,nnucbin=          72           1
#
#     inucbin=          72
#
#    ibin,nnucbin=          73           1
#
#     inucbin=          73
#
#    ibin,nnucbin=          74           1
#
#     inucbin=          74
#
#    ibin,nnucbin=          75           1
#
#     inucbin=          75
#
#    ibin,nnucbin=          76           1
#
#     inucbin=          76
#
#    ibin,nnucbin=          77           1
#
#     inucbin=          77
#
#    ibin,nnucbin=          78           1
#
#     inucbin=          78
#
#    ibin,nnucbin=          79           1
#
#     inucbin=          79
#
#    ibin,nnucbin=          80           1
#
#     inucbin=          80
#
#
#
#  Groups (from, to) =            2           1
#
#    None for bin            1
#
#    ibin,nnucbin=           2           1
#
#     inucbin=           1
#
#    ibin,nnucbin=           3           1
#
#     inucbin=           2
#
#    ibin,nnucbin=           4           1
#
#     inucbin=           3
#
#    ibin,nnucbin=           5           1
#
#     inucbin=           4
#
#    ibin,nnucbin=           6           1
#
#     inucbin=           5
#
#    ibin,nnucbin=           7           1
#
#     inucbin=           6
#
#    ibin,nnucbin=           8           1
#
#     inucbin=           7
#
#    ibin,nnucbin=           9           1
#
#     inucbin=           8
#
#    ibin,nnucbin=          10           1
#
#     inucbin=           9
#
#    ibin,nnucbin=          11           1
#
#     inucbin=          10
#
#    ibin,nnucbin=          12           1
#
#     inucbin=          11
#
#    ibin,nnucbin=          13           1
#
#     inucbin=          12
#
#    ibin,nnucbin=          14           1
#
#     inucbin=          13
#
#    ibin,nnucbin=          15           1
#
#     inucbin=          14
#
#    ibin,nnucbin=          16           1
#
#     inucbin=          15
#
#    ibin,nnucbin=          17           1
#
#     inucbin=          16
#
#    ibin,nnucbin=          18           1
#
#     inucbin=          17
#
#    ibin,nnucbin=          19           1
#
#     inucbin=          18
#
#    ibin,nnucbin=          20           1
#
#     inucbin=          19
#
#    ibin,nnucbin=          21           1
#
#     inucbin=          20
#
#    ibin,nnucbin=          22           1
#
#     inucbin=          21
#
#    ibin,nnucbin=          23           1
#
#     inucbin=          22
#
#    ibin,nnucbin=          24           1
#
#     inucbin=          23
#
#    ibin,nnucbin=          25           1
#
#     inucbin=          24
#
#    ibin,nnucbin=          26           1
#
#     inucbin=          25
#
#    ibin,nnucbin=          27           1
#
#     inucbin=          26
#
#    ibin,nnucbin=          28           1
#
#     inucbin=          27
#
#    ibin,nnucbin=          29           1
#
#     inucbin=          28
#
#    ibin,nnucbin=          30           1
#
#     inucbin=          29
#
#    ibin,nnucbin=          31           1
#
#     inucbin=          30
#
#    ibin,nnucbin=          32           1
#
#     inucbin=          31
#
#    ibin,nnucbin=          33           1
#
#     inucbin=          32
#
#    ibin,nnucbin=          34           1
#
#     inucbin=          33
#
#    ibin,nnucbin=          35           1
#
#     inucbin=          34
#
#    ibin,nnucbin=          36           1
#
#     inucbin=          35
#
#    ibin,nnucbin=          37           1
#
#     inucbin=          36
#
#    ibin,nnucbin=          38           1
#
#     inucbin=          37
#
#    ibin,nnucbin=          39           1
#
#     inucbin=          38
#
#    ibin,nnucbin=          40           1
#
#     inucbin=          39
#
#    ibin,nnucbin=          41           1
#
#     inucbin=          40
#
#    ibin,nnucbin=          42           1
#
#     inucbin=          41
#
#    ibin,nnucbin=          43           1
#
#     inucbin=          42
#
#    ibin,nnucbin=          44           1
#
#     inucbin=          43
#
#    ibin,nnucbin=          45           1
#
#     inucbin=          44
#
#    ibin,nnucbin=          46           1
#
#     inucbin=          45
#
#    ibin,nnucbin=          47           1
#
#     inucbin=          46
#
#    ibin,nnucbin=          48           1
#
#     inucbin=          47
#
#    ibin,nnucbin=          49           1
#
#     inucbin=          48
#
#    ibin,nnucbin=          50           1
#
#     inucbin=          49
#
#    ibin,nnucbin=          51           1
#
#     inucbin=          50
#
#    ibin,nnucbin=          52           1
#
#     inucbin=          51
#
#    ibin,nnucbin=          53           1
#
#     inucbin=          52
#
#    ibin,nnucbin=          54           1
#
#     inucbin=          53
#
#    ibin,nnucbin=          55           1
#
#     inucbin=          54
#
#    ibin,nnucbin=          56           1
#
#     inucbin=          55
#
#    ibin,nnucbin=          57           1
#
#     inucbin=          56
#
#    ibin,nnucbin=          58           1
#
#     inucbin=          57
#
#    ibin,nnucbin=          59           1
#
#     inucbin=          58
#
#    ibin,nnucbin=          60           1
#
#     inucbin=          59
#
#    ibin,nnucbin=          61           1
#
#     inucbin=          60
#
#    ibin,nnucbin=          62           1
#
#     inucbin=          61
#
#    ibin,nnucbin=          63           1
#
#     inucbin=          62
#
#    ibin,nnucbin=          64           1
#
#     inucbin=          63
#
#    ibin,nnucbin=          65           1
#
#     inucbin=          64
#
#    ibin,nnucbin=          66           1
#
#     inucbin=          65
#
#    ibin,nnucbin=          67           1
#
#     inucbin=          66
#
#    ibin,nnucbin=          68           1
#
#     inucbin=          67
#
#    ibin,nnucbin=          69           1
#
#     inucbin=          68
#
#    ibin,nnucbin=          70           1
#
#     inucbin=          69
#
#    ibin,nnucbin=          71           1
#
#     inucbin=          70
#
#    ibin,nnucbin=          72           1
#
#     inucbin=          71
#
#    ibin,nnucbin=          73           1
#
#     inucbin=          72
#
#    ibin,nnucbin=          74           1
#
#     inucbin=          73
#
#    ibin,nnucbin=          75           1
#
#     inucbin=          74
#
#    ibin,nnucbin=          76           1
#
#     inucbin=          75
#
#    ibin,nnucbin=          77           1
#
#     inucbin=          76
#
#    ibin,nnucbin=          78           1
#
#     inucbin=          77
#
#    ibin,nnucbin=          79           1
#
#     inucbin=          78
#
#    ibin,nnucbin=          80           1
#
#     inucbin=          79
#
#
#
#  Groups (from, to) =            2           2
#
#    ibin,nnucbin=           1           1
#
#     inucbin=           1
#
#    ibin,nnucbin=           2           1
#
#     inucbin=           2
#
#    ibin,nnucbin=           3           1
#
#     inucbin=           3
#
#    ibin,nnucbin=           4           1
#
#     inucbin=           4
#
#    ibin,nnucbin=           5           1
#
#     inucbin=           5
#
#    ibin,nnucbin=           6           1
#
#     inucbin=           6
#
#    ibin,nnucbin=           7           1
#
#     inucbin=           7
#
#    ibin,nnucbin=           8           1
#
#     inucbin=           8
#
#    ibin,nnucbin=           9           1
#
#     inucbin=           9
#
#    ibin,nnucbin=          10           1
#
#     inucbin=          10
#
#    ibin,nnucbin=          11           1
#
#     inucbin=          11
#
#    ibin,nnucbin=          12           1
#
#     inucbin=          12
#
#    ibin,nnucbin=          13           1
#
#     inucbin=          13
#
#    ibin,nnucbin=          14           1
#
#     inucbin=          14
#
#    ibin,nnucbin=          15           1
#
#     inucbin=          15
#
#    ibin,nnucbin=          16           1
#
#     inucbin=          16
#
#    ibin,nnucbin=          17           1
#
#     inucbin=          17
#
#    ibin,nnucbin=          18           1
#
#     inucbin=          18
#
#    ibin,nnucbin=          19           1
#
#     inucbin=          19
#
#    ibin,nnucbin=          20           1
#
#     inucbin=          20
#
#    ibin,nnucbin=          21           1
#
#     inucbin=          21
#
#    ibin,nnucbin=          22           1
#
#     inucbin=          22
#
#    ibin,nnucbin=          23           1
#
#     inucbin=          23
#
#    ibin,nnucbin=          24           1
#
#     inucbin=          24
#
#    ibin,nnucbin=          25           1
#
#     inucbin=          25
#
#    ibin,nnucbin=          26           1
#
#     inucbin=          26
#
#    ibin,nnucbin=          27           1
#
#     inucbin=          27
#
#    ibin,nnucbin=          28           1
#
#     inucbin=          28
#
#    ibin,nnucbin=          29           1
#
#     inucbin=          29
#
#    ibin,nnucbin=          30           1
#
#     inucbin=          30
#
#    ibin,nnucbin=          31           1
#
#     inucbin=          31
#
#    ibin,nnucbin=          32           1
#
#     inucbin=          32
#
#    ibin,nnucbin=          33           1
#
#     inucbin=          33
#
#    ibin,nnucbin=          34           1
#
#     inucbin=          34
#
#    ibin,nnucbin=          35           1
#
#     inucbin=          35
#
#    ibin,nnucbin=          36           1
#
#     inucbin=          36
#
#    ibin,nnucbin=          37           1
#
#     inucbin=          37
#
#    ibin,nnucbin=          38           1
#
#     inucbin=          38
#
#    ibin,nnucbin=          39           1
#
#     inucbin=          39
#
#    ibin,nnucbin=          40           1
#
#     inucbin=          40
#
#    ibin,nnucbin=          41           1
#
#     inucbin=          41
#
#    ibin,nnucbin=          42           1
#
#     inucbin=          42
#
#    ibin,nnucbin=          43           1
#
#     inucbin=          43
#
#    ibin,nnucbin=          44           1
#
#     inucbin=          44
#
#    ibin,nnucbin=          45           1
#
#     inucbin=          45
#
#    ibin,nnucbin=          46           1
#
#     inucbin=          46
#
#    ibin,nnucbin=          47           1
#
#     inucbin=          47
#
#    ibin,nnucbin=          48           1
#
#     inucbin=          48
#
#    ibin,nnucbin=          49           1
#
#     inucbin=          49
#
#    ibin,nnucbin=          50           1
#
#     inucbin=          50
#
#    ibin,nnucbin=          51           1
#
#     inucbin=          51
#
#    ibin,nnucbin=          52           1
#
#     inucbin=          52
#
#    ibin,nnucbin=          53           1
#
#     inucbin=          53
#
#    ibin,nnucbin=          54           1
#
#     inucbin=          54
#
#    ibin,nnucbin=          55           1
#
#     inucbin=          55
#
#    ibin,nnucbin=          56           1
#
#     inucbin=          56
#
#    ibin,nnucbin=          57           1
#
#     inucbin=          57
#
#    ibin,nnucbin=          58           1
#
#     inucbin=          58
#
#    ibin,nnucbin=          59           1
#
#     inucbin=          59
#
#    ibin,nnucbin=          60           1
#
#     inucbin=          60
#
#    ibin,nnucbin=          61           1
#
#     inucbin=          61
#
#    ibin,nnucbin=          62           1
#
#     inucbin=          62
#
#    ibin,nnucbin=          63           1
#
#     inucbin=          63
#
#    ibin,nnucbin=          64           1
#
#     inucbin=          64
#
#    ibin,nnucbin=          65           1
#
#     inucbin=          65
#
#    ibin,nnucbin=          66           1
#
#     inucbin=          66
#
#    ibin,nnucbin=          67           1
#
#     inucbin=          67
#
#    ibin,nnucbin=          68           1
#
#     inucbin=          68
#
#    ibin,nnucbin=          69           1
#
#     inucbin=          69
#
#    ibin,nnucbin=          70           1
#
#     inucbin=          70
#
#    ibin,nnucbin=          71           1
#
#     inucbin=          71
#
#    ibin,nnucbin=          72           1
#
#     inucbin=          72
#
#    ibin,nnucbin=          73           1
#
#     inucbin=          73
#
#    ibin,nnucbin=          74           1
#
#     inucbin=          74
#
#    ibin,nnucbin=          75           1
#
#     inucbin=          75
#
#    ibin,nnucbin=          76           1
#
#     inucbin=          76
#
#    ibin,nnucbin=          77           1
#
#     inucbin=          77
#
#    ibin,nnucbin=          78           1
#
#     inucbin=          78
#
#    ibin,nnucbin=          79           1
#
#     inucbin=          79
#
#    ibin,nnucbin=          80           1
#
#     inucbin=          80
#
#
#
# Particle nucleation mapping arrays (setupnuc):
#
# inucgas  :       2     0     3
#
# inuc2elem:       1     3
#
# ievp2elem:       0     0     1
#
#
#
# Particle nucleation mapping arrays (setupnuc):
#
# inucgas  :       0     0     0
#
# inuc2elem:
#
# ievp2elem:       0     0     1
#
#
#
# Particle nucleation mapping arrays (setupnuc):
#
# inucgas  :       0     0     0
#
# inuc2elem:
#
# ievp2elem:       0     0     1
#
#
#
# solute number   :       1
#
# solute name:    Sulfuric Acid
#
# molecular weight:     9.808E+01
#
# mass density    :     1.840E+00
#
#
#
#  level          zc           p           t
#
#                (m)        (Pa)         (K)
#
#      1    5415.761************    6736.446
#
#      2   16174.332************    6644.265
#
#      3   26785.685************    6550.461
#
#      4   37247.226************    6455.089
#
#      5   47556.451************    6358.211
#
#      6   57710.955************    6259.893
#
#      7   67708.439************    6160.206
#
#      8   77546.715************    6059.227
#
#      9   87223.721************    5957.037
#
#     10   96737.523************    5853.721
#
#     11  106086.322************    5749.369
#
#     12  115268.464************    5644.075
#
#     13  124282.444************    5537.937
#
#     14  133126.913************    5431.054
#
#     15  141800.683************    5323.530
#
#     16  150302.730************    5215.472
#
#     17  158632.201************    5106.988
#
#     18  166788.41688416757.881    4998.189
#
#     19  174770.87076705818.649    4889.185
#
#     20  182579.23866546011.815    4780.089
#
#     21  190213.37257731887.443    4671.013
#
#     22  197673.30450085207.766    4562.071
#
#     23  204959.24943451342.890    4453.374
#
#     24  212071.59637696143.895    4345.033
#
#     25  219010.91532703230.096    4237.158
#
#     26  225777.95028371635.617    4129.856
#
#     27  232373.61724613767.667    4023.232
#
#     28  238798.99821353635.263    3917.390
#
#     29  245055.34318525312.545    3812.429
#
#     30  251144.05716071605.639    3708.445
#
#     31  257066.70113942896.088    3605.530
#
#     32  262824.98312096137.478    3503.772
#
#     33  268420.75010493984.964    3403.256
#
#     34  273855.986 9104040.081    3304.060
#
#     35  279132.799 7898195.593    3206.259
#
#     36  284253.418 6852067.111    3109.923
#
#     37  289149.876 5944500.000    3021.495
#
#     38  293832.173 5157100.000    2940.305
#
#     39  298379.412 4474000.000    2859.215
#
#     40  302792.877 3881400.000    2778.360
#
#     41  307073.082 3367250.000    2697.890
#
#     42  311221.191 2921200.000    2617.680
#
#     43  315239.484 2534250.000    2537.660
#
#     44  319128.958 2198600.000    2458.205
#
#     45  322892.423 1907400.000    2379.605
#
#     46  326531.710 1654750.000    2301.725
#
#     47  330048.649 1435550.000    2224.780
#
#     48  333445.065 1245400.000    2149.150
#
#     49  336723.906 1080450.000    2074.890
#
#     50  339888.620  937320.000    2002.040
#
#     51  342941.107  813165.000    1930.830
#
#     52  345908.133  705455.000    1876.455
#
#     53  348818.108  612010.000    1840.145
#
#     54  351669.258  530945.000    1802.705
#
#     55  354451.982  460620.000    1759.065
#
#     56  357150.707  399605.000    1705.440
#
#     57  359728.425  346670.000    1628.550
#
#     58  362168.701  300750.000    1541.650
#
#     59  364495.948  260915.000    1470.290
#
#     60  366730.861  226355.000    1411.830
#
#     61  368880.235  196370.000    1357.575
#
#     62  370945.952  170360.000    1304.810
#
#     63  372930.994  147795.000    1253.765
#
#     64  374845.777  128215.000    1209.245
#
#     65  376696.555  111235.000    1169.475
#
#     66  378482.538   96503.500    1128.700
#
#     67  380205.830   83719.000    1088.725
#
#     68  381869.833   72629.500    1051.245
#
#     69  383477.684   63009.000    1016.005
#
#     70  385031.533   54663.000     982.155
#
#     71  386534.176   47422.500     949.885
#
#     72  387988.366   41141.000     919.345
#
#     73  389397.042   35691.500     890.610
#
#     74  390763.108   30964.000     863.725
#
#     75  392089.568   26862.500     838.640
#
#     76  393378.940   23304.000     815.125
#
#     77  394633.346   20217.000     793.050
#
#     78  395855.094   17539.000     772.430
#
#     79  397046.381   15216.000     753.270
#
#     80  398209.580   13200.500     735.425
#
#     81  399346.380   11452.000     718.770
#
#     82  400458.611    9935.250     703.290
#
#     83  401548.105    8619.200     688.820
#
#     84  402615.914    7477.550     675.150
#
#     85  403663.227    6487.100     662.180
#
#     86  404691.160    5627.800     649.890
#
#     87  405700.884    4882.350     638.405
#
#     88  406693.833    4235.650     627.800
#
#     89  407671.340    3674.600     618.035
#
#     90  408634.648    3187.900     609.100
#
#     91  409585.018    2765.600     600.820
#
#     92  410522.560    2399.250     592.735
#
#     93  411447.166    2081.450     584.585
#
#     94  412359.108    1805.750     576.600
#
#     95  413259.587    1566.600     569.425
#
#     96  414150.398    1359.100     563.245
#
#     97  415032.777    1179.050     557.800
#
#     98  415907.403    1022.860     552.940
#
#     99  416774.535     887.385     548.300
#
#    100  417634.571     769.845     543.770
#
#    101  418487.839     667.870     539.470
#
#    102  419334.657     579.405     535.405
#
#    103  420175.368     502.660     531.560
#
#    104  421010.122     436.080     527.790
#
#    105  421838.601     378.315     523.785
#
#    106  422660.157     328.205     519.450
#
#    107  423474.347     284.735     514.820
#
#    108  424280.652     247.020     509.800
#
#    109  425078.560     214.300     504.480
#
#    110  425868.291     185.915     499.330
#
#    111  426650.585     161.290     494.630
#
#    112  427425.960     139.925     490.215
#
#    113  428194.621     121.390     485.970
#
#    114  428956.834     105.310     481.885
#
#    115  429712.813      91.360     477.945
#
#    116  430462.629      79.260     474.140
#
#    117  431206.844      68.760     470.455
#
#    118  431945.447      59.650     466.880
#
#    119  432678.305      51.750     463.425
#
#    120  433406.058      44.895     460.100
#
#    121  434128.470      38.950     456.910
#
#    122  434846.489      33.790     453.865
#
#    123  435559.575      29.315     450.990
#
#    124  436268.108      25.435     448.310
#
#    125  436973.483      22.065     445.855
#
#    126  437675.878      19.140     443.690
#
#
#
#  level          zl          pl
#
#                (m)        (Pa)
#
#      1       0.000************
#
#      2   10831.521************
#
#      3   21517.142************
#
#      4   32054.227************
#
#      5   42440.225************
#
#      6   52672.678************
#
#      7   62749.233************
#
#      8   72667.644************
#
#      9   82425.786************
#
#     10   92021.657************
#
#     11  101453.389************
#
#     12  110719.255************
#
#     13  119817.673************
#
#     14  128747.215************
#
#     15  137506.611************
#
#     16  146094.754************
#
#     17  154510.705************
#
#     18  162753.69694687513.222
#
#     19  170823.13582146002.540
#
#     20  178718.60571265634.758
#
#     21  186439.87061826388.873
#
#     22  193986.87353637386.014
#
#     23  201359.73646533029.519
#
#     24  208558.76140369656.262
#
#     25  215584.43135022631.528
#
#     26  222437.40030383828.665
#
#     27  229118.50026359442.568
#
#     28  235628.73322868092.766
#
#     29  241969.26319839177.760
#
#     30  248141.42217211447.331
#
#     31  254146.69214931763.947
#
#     32  259986.71012954028.228
#
#     33  265663.25511238246.729
#
#     34  271178.245 9749723.199
#
#     35  276533.727 8458356.962
#
#     36  281731.871 7338034.223
#
#     37  286774.964 6366100.000
#
#     38  291524.789 5522900.000
#
#     39  296139.558 4791300.000
#
#     40  300619.265 4156700.000
#
#     41  304966.488 3606100.000
#
#     42  309179.676 3128400.000
#
#     43  313262.705 2714000.000
#
#     44  317216.263 2354500.000
#
#     45  321041.653 2042700.000
#
#     46  324743.193 1772100.000
#
#     47  328320.227 1537400.000
#
#     48  331777.070 1333700.000
#
#     49  335113.059 1157100.000
#
#     50  338334.754 1003800.000
#
#     51  341442.486  870840.000
#
#     52  344439.728  755490.000
#
#     53  347376.537  655420.000
#
#     54  350259.680  568600.000
#
#     55  353078.836  493290.000
#
#     56  355825.128  427950.000
#
#     57  358476.287  371260.000
#
#     58  360980.564  322080.000
#
#     59  363356.839  279420.000
#
#     60  365635.057  242410.000
#
#     61  367826.665  210300.000
#
#     62  369933.804  182440.000
#
#     63  371958.101  158280.000
#
#     64  373903.887  137310.000
#
#     65  375787.668  119120.000
#
#     66  377605.443  103350.000
#
#     67  379359.634   89657.000
#
#     68  381052.026   77781.000
#
#     69  382687.641   67478.000
#
#     70  384267.727   58540.000
#
#     71  385795.339   50786.000
#
#     72  387273.013   44059.000
#
#     73  388703.719   38223.000
#
#     74  390090.364   33160.000
#
#     75  391435.852   28768.000
#
#     76  392743.283   24957.000
#
#     77  394014.597   21651.000
#
#     78  395252.094   18783.000
#
#     79  396458.093   16295.000
#
#     80  397634.669   14137.000
#
#     81  398784.490   12264.000
#
#     82  399908.270   10640.000
#
#     83  401008.953    9230.500
#
#     84  402087.258    8007.900
#
#     85  403144.569    6947.200
#
#     86  404181.885    6027.000
#
#     87  405200.436    5228.600
#
#     88  406201.331    4536.100
#
#     89  407186.334    3935.200
#
#     90  408156.347    3414.000
#
#     91  409112.950    2961.800
#
#     92  410057.086    2569.400
#
#     93  410988.033    2229.100
#
#     94  411906.298    1933.800
#
#     95  412811.919    1677.700
#
#     96  413707.254    1455.500
#
#     97  414593.542    1262.700
#
#     98  415472.012    1095.400
#
#     99  416342.794     950.320
#
#    100  417206.276     824.450
#
#    101  418062.866     715.240
#
#    102  418912.812     620.500
#
#    103  419756.502     538.310
#
#    104  420594.234     467.010
#
#    105  421426.010     405.150
#
#    106  422251.192     351.480
#
#    107  423069.122     304.930
#
#    108  423879.571     264.540
#
#    109  424681.732     229.500
#
#    110  425475.388     199.100
#
#    111  426261.193     172.730
#
#    112  427039.978     149.850
#
#    113  427811.943     130.000
#
#    114  428577.300     112.780
#
#    115  429336.368      97.840
#
#    116  430089.259      84.880
#
#    117  430835.999      73.640
#
#    118  431577.688      63.880
#
#    119  432313.205      55.420
#
#    120  433043.405      48.080
#
#    121  433768.710      41.710
#
#    122  434488.231      36.190
#
#    123  435204.746      31.390
#
#    124  435914.403      27.240
#
#    125  436621.812      23.630
#
#    126  437325.153      20.500
#
#    127  438026.603      17.780
#
#
#
#    0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000        0.0000000000000000
#
#  istep, time           1   0.0000000000000000      my_first_carma
#
#  istep, time           2   250.00000000000000      my_first_carma
#
#  istep, time           3   500.00000000000000      my_first_carma
#
#  istep, time           4   750.00000000000000      my_first_carma
#
#  istep, time           5   1000.0000000000000      my_first_carma
#
#  istep, time           6   1250.0000000000000      my_first_carma
#
#  istep, time           7   1500.0000000000000      my_first_carma
#
#  istep, time           8   1750.0000000000000      my_first_carma
#
#  istep, time           9   2000.0000000000000      my_first_carma
#
#  istep, time          10   2250.0000000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#  istep, time          11   2500.0000000000000      my_first_carma
#
#  istep, time          12   2750.0000000000000      my_first_carma
#
#  istep, time          13   3000.0000000000000      my_first_carma
#
#  istep, time          14   3250.0000000000000      my_first_carma
#
#  istep, time          15   3500.0000000000000      my_first_carma
#
#  istep, time          16   3750.0000000000000      my_first_carma
#
#  istep, time          17   4000.0000000000000      my_first_carma
#
#  istep, time          18   4250.0000000000000      my_first_carma
#
#  istep, time          19   4500.0000000000000      my_first_carma
#
#  istep, time          20   4750.0000000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#  istep, time          21   5000.0000000000000      my_first_carma
#
#  istep, time          22   5250.0000000000000      my_first_carma
#
#  istep, time          23   5500.0000000000000      my_first_carma
#
#  istep, time          24   5750.0000000000000      my_first_carma
#
#  istep, time          25   6000.0000000000000      my_first_carma
#
#  istep, time          26   6250.0000000000000      my_first_carma
#
#  istep, time          27   6500.0000000000000      my_first_carma
#
#  istep, time          28   6750.0000000000000      my_first_carma
#
#  istep, time          29   7000.0000000000000      my_first_carma
#
#  istep, time          30   7250.0000000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#  istep, time          31   7500.0000000000000      my_first_carma
#
#  istep, time          32   7750.0000000000000      my_first_carma
#
#  istep, time          33   8000.0000000000000      my_first_carma
#
#  istep, time          34   8250.0000000000000      my_first_carma
#
#  istep, time          35   8500.0000000000000      my_first_carma
#
#  istep, time          36   8750.0000000000000      my_first_carma
#
#  istep, time          37   9000.0000000000000      my_first_carma
#
#  istep, time          38   9250.0000000000000      my_first_carma
#
#  istep, time          39   9500.0000000000000      my_first_carma
#
#  istep, time          40   9750.0000000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#  istep, time          41   10000.000000000000      my_first_carma
#
#  istep, time          42   10250.000000000000      my_first_carma
#
#  istep, time          43   10500.000000000000      my_first_carma
#
#  istep, time          44   10750.000000000000      my_first_carma
#
#  istep, time          45   11000.000000000000      my_first_carma
#
#  istep, time          46   11250.000000000000      my_first_carma
#
#  istep, time          47   11500.000000000000      my_first_carma
#
#  istep, time          48   11750.000000000000      my_first_carma
#
#  istep, time          49   12000.000000000000      my_first_carma
#
#  istep, time          50   12250.000000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#  istep, time          51   12500.000000000000      my_first_carma
#
#  istep, time          52   12750.000000000000      my_first_carma
#
#  istep, time          53   13000.000000000000      my_first_carma
#
#  istep, time          54   13250.000000000000      my_first_carma
#
#  istep, time          55   13500.000000000000      my_first_carma
#
#  istep, time          56   13750.000000000000      my_first_carma
#
#  istep, time          57   14000.000000000000      my_first_carma
#
#  istep, time          58   14250.000000000000      my_first_carma
#
#  istep, time          59   14500.000000000000      my_first_carma
#
#  istep, time          60   14750.000000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#  istep, time          61   15000.000000000000      my_first_carma
#
#  istep, time          62   15250.000000000000      my_first_carma
#
#  istep, time          63   15500.000000000000      my_first_carma
#
#  istep, time          64   15750.000000000000      my_first_carma
#
#  istep, time          65   16000.000000000000      my_first_carma
#
#  istep, time          66   16250.000000000000      my_first_carma
#
#  istep, time          67   16500.000000000000      my_first_carma
#
#  istep, time          68   16750.000000000000      my_first_carma
#
#  istep, time          69   17000.000000000000      my_first_carma
#
#  istep, time          70   17250.000000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#  istep, time          71   17500.000000000000      my_first_carma
#
#  istep, time          72   17750.000000000000      my_first_carma
#
#  istep, time          73   18000.000000000000      my_first_carma
#
#  istep, time          74   18250.000000000000      my_first_carma
#
#  istep, time          75   18500.000000000000      my_first_carma
#
#  istep, time          76   18750.000000000000      my_first_carma
#
#  istep, time          77   19000.000000000000      my_first_carma
#
#  istep, time          78   19250.000000000000      my_first_carma
#
#  istep, time          79   19500.000000000000      my_first_carma
#
#  istep, time          80   19750.000000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#  istep, time          81   20000.000000000000      my_first_carma
#
#  istep, time          82   20250.000000000000      my_first_carma
#
#  istep, time          83   20500.000000000000      my_first_carma
#
#  istep, time          84   20750.000000000000      my_first_carma
#
#  istep, time          85   21000.000000000000      my_first_carma
#
#  istep, time          86   21250.000000000000      my_first_carma
#
#  istep, time          87   21500.000000000000      my_first_carma
#
#  istep, time          88   21750.000000000000      my_first_carma
#
#  istep, time          89   22000.000000000000      my_first_carma
#
#  istep, time          90   22250.000000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#  istep, time          91   22500.000000000000      my_first_carma
#
#  istep, time          92   22750.000000000000      my_first_carma
#
#  istep, time          93   23000.000000000000      my_first_carma
#
#  istep, time          94   23250.000000000000      my_first_carma
#
#  istep, time          95   23500.000000000000      my_first_carma
#
#  istep, time          96   23750.000000000000      my_first_carma
#
#  istep, time          97   24000.000000000000      my_first_carma
#
#  istep, time          98   24250.000000000000      my_first_carma
#
#  istep, time          99   24500.000000000000      my_first_carma
#
#  istep, time         100   24750.000000000000      my_first_carma
#
#  Recorded
#
#  write restart file
#
#
#
#  CARMA_Destroy() ...
#
#  Done

# %% [markdown]
# Feel free to remove the `suppress_output=True` statement, it is just there to stop this notebook from being cluttered with print statements.  Note that when you call `carma.run()` a directory with the name `"my_first_carma"` should have been created.  The directory stores the state of the model along with the model output—do not move or delete it while the model is running.  The next tutorial will go over how to read the output from that directory.
